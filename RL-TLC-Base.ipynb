# %% [markdown]
# # Reinforecement Learning for Traffic Light Control

# %% [markdown]
# Required packages or environments:
#
# * Python 3.6
# * SUMO 0.32 with TraCI module. Click the [link](https://sumo.dlr.de/docs/SUMO_User_Documentation.html) for user documentation
# * Keras 2.2.0 and Tensorflow 1.9.0

# %% [markdown]
# ## Setting Up the environment through SUMO and TRACI

# %%
from __future__ import absolute_import
from __future__ import print_function

import os
import sys
import optparse
import argparse
import random
from pprint import pprint as pp
import numpy as np

# %% [markdown]
# ### Import python modules from the SUMO_HOME/tools directory

# %%
if 'SUMO_HOME' in os.environ:
    tools = os.path.join(os.environ['SUMO_HOME'], 'tools')
    sys.path.append(tools)
else:
    sys.exit("please declare environment variable 'SUMO_HOME'")

# %% [markdown]
# ### Simulation environment setting up

# %%
from sumolib import checkBinary  
import traci  # noqa
import traci.constants as tc

# %% [markdown]
# ### Generating route file (data/road.rou.xml) based on the demand per second from differnt directions

# %%
def generate_routefile():
    random.seed(42)  # make tests reproducible
    N = 3600  # number of time steps
    # demand per second from different directions
    pEB = 1. / 10
    pWB = 1. / 11
    pSB = 1. / 15
    pNB = 1. / 25
    with open("data/road.rou.xml", "w") as routes:
        print("""<routes>
        <vType id="typeWE" accel="0.8" decel="4.5" sigma="0.5" length="5" minGap="2.5" maxSpeed="16.67" \
guiShape="passenger"/>
        <vType id="typeNS" accel="0.8" decel="4.5" sigma="0.5" length="7" minGap="3" maxSpeed="25" guiShape="bus"/>

        <route id="EastBound" edges="W-0W 0W-0 0-0E 0E-E" />
        <route id="WestBound" edges="E-0E 0E-0 0-0W 0W-W" />
        <route id="SouthBound" edges="N-0N 0N-0 0-0S 0S-S" />
        <route id="NorthBound" edges="S-0S 0S-0 0-0N 0N-N" />""", file=routes)
        vehNr = 0
        for i in range(N):
            if random.uniform(0, 1) < pEB:
                print('    <vehicle id="EastBound_%i" type="typeWE" route="EastBound" depart="%i" />' % (
                    vehNr, i), file=routes)
                vehNr += 1
            if random.uniform(0, 1) < pWB:
                print('    <vehicle id="WestBound_%i" type="typeWE" route="WestBound" depart="%i" />' % (
                    vehNr, i), file=routes)
                vehNr += 1
            if random.uniform(0, 1) < pSB:
                print('    <vehicle id="SouthBound_%i" type="typeNS" route="SouthBound" depart="%i" color="1,0,0"/>' % (
                    vehNr, i), file=routes)
                vehNr += 1
            if random.uniform(0, 1) < pNB:
                print('    <vehicle id="NorthBound_%i" type="typeNS" route="NorthBound" depart="%i" color="1,0,0"/>' % (
                    vehNr, i), file=routes)
                vehNr += 1
        print("</routes>", file=routes)

# %%
# The program looks like this
#    <tlLogic id="tl0" type="static" programID="0" offset="0">
# the locations of the tls are      NESW
#        <phase duration="41" state="GGrrGGrr"/>
#        <phase duration="4" state="yyrryyrr"/>
#        <phase duration="41" state="rrGGrrGG"/>
#        <phase duration="4" state="rryyrryy"/>
#    </tlLogic>

# %%
def run():
    """execute the TraCI control loop"""
#    step = 0
    # we start with phase 2 where EW has green
   
    traci.junction.subscribeContext("tl0", tc.CMD_GET_VEHICLE_VARIABLE, 300, [tc.VAR_SPEED, tc.VAR_WAITING_TIME]) 
    print(traci.junction.getContextSubscriptionResults("tl0"))
#   traci.trafficlight.setPhase("tl0", 2)
#    while traci.lane.getLastStepVehicleNumber("0W-0_0") <200:
#   while traci.simulation.getMinExpectedNumber() > 0:        
    for step in range(10):
        print(f'\n_______________' \
              f"(step {step}):", end=' ')
        print(f"Delta = {traci.simulation.getDeltaT()} s", end='  _  ')
        print(f'# MinExpectedNumber: {traci.simulation.getMinExpectedNumber()}', end='  ')
        
        print(f'TL Phase {traci.trafficlight.getPhase("tl0")} _ ' \
              f'{traci.trafficlight.getRedYellowGreenState("tl0")}' \
              f'({traci.trafficlight.getPhaseDuration("tl0")} s) _ '\
              f'next phase at {traci.trafficlight.getNextSwitch("tl0")}s')
        
        traci.simulationStep()
        print(f' #EB approaching TL : {traci.edge.getLastStepVehicleNumber("0W-0")}' \
              f'  _  # vehicles waiting: {traci.edge.getLastStepHaltingNumber("0W-0")}' \
              f'EB ttl waiting time: {traci.edge.getWaitingTime("0W-0")}')
        print(traci.junction.getContextSubscriptionResults("tl0"))
#    if traci.trafficlight.getPhase("tl0") == 2:
            # we are not already switching
#           if traci.inductionloop.getLastStepVehicleNumber("tl0") > 0:
                # there is a vehicle from the north, switch
#       traci.trafficlight.setPhase("tl0", 3)
#           else:
                # otherwise try to keep green for EW
#               traci.trafficlight.setPhase("tl0", 2)
#        eb = traci.lane.getLastStepVehicleNumber("0W-0_0")
#        step += 1
#        print("Step "+ str(step))
#        print('Eastbound vechicles : ', eb)
    #traci.close()
    #sys.stdout.flush()

# %% [markdown]
# ### TrafficSignal Class for traffic lights of an intersection,  via TRACI API to retriev status info and change traffice lights phases.

# %%
class TrafficSignal:
    """
    This class represents a Traffic Lights of an intersection,
    via TRACI API to retriev status info and change traffice lights phases.
    """
    def __init__(self, tlsID,programID,delta_time, min_green, max_green, phases):
        self.id = tlsID
        self.programID = programID
        self.time_on_phase = 0.0
        self.delta_time = delta_time
        self.min_green = min_green
        self.max_green = max_green
        self.green_phase = 0
        self.num_green_phases = len(phases) // 2
        self.lanes = list(dict.fromkeys(traci.trafficlight.getControlledLanes(self.id)))  # remove duplicates and keep order
        self.edges = self._compute_edges()
        self.edges_capacity = self._compute_edges_capacity()

        logic = traci.trafficlight.Logic("new-program", 0, 0, phases=phases)
        traci.trafficlight.setCompleteRedYellowGreenDefinition(self.id, logic)

# %%
import argparse
def get_options():
    optParser = argparse.ArgumentParser()
    optParser.add_argument("--nogui", action="store_true",
                         default=False, help="run the commandline version of sumo")
#    options, args = optParser.parse_args()
    options, args = optParser.parse_known_args()
#    optParser.print_help()
    return options

# %% [markdown]
# this is the main entry point of the simulation

# %%
if __name__ == "__main__":
    options = get_options()
#    print(options)
    # this script has been called from the command line. It will start sumo as a
    # server, then connect and run
    if options.nogui:
        sumoBinary = checkBinary('sumo')
    else:
        sumoBinary = checkBinary('sumo-gui')

    # first, generate the route file for this simulation
    generate_routefile()

    # this is the normal way of using traci. sumo is started as a
    # subprocess and then the python script connects and runs
    traci.start([sumoBinary, "-c", "data/road.sumocfg",
                             "--tripinfo-output", "tripinfo.xml"])
    class durationRewardStepListener(traci.StepListener):
        def step(self, t=0):

            print("ExampleListener called at time %s ms." % traci.simulation.getTime())

            return True

    duration_listener = durationRewardStepListener()
    traci.addStepListener(duration_listener)
        
    run()
# Out:
#  Retrying in 1 seconds
# Could not connect to TraCI server at localhost:50452 [Errno 61] Connection refused
#  Retrying in 2 seconds
# None
#
# _______________(step 0): Delta = 1.0 s  _  # MinExpectedNumber: 2  TL Phase 0 _ GGrrGGrr(41.0 s) _ next phase at 41.0s
# ExampleListener called at time 1.0 ms.
#  #EB approaching TL : 0  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# None
#
# _______________(step 1): Delta = 1.0 s  _  # MinExpectedNumber: 2  TL Phase 0 _ GGrrGGrr(41.0 s) _ next phase at 41.0s
# ExampleListener called at time 2.0 ms.
#  #EB approaching TL : 0  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# None
#
# _______________(step 2): Delta = 1.0 s  _  # MinExpectedNumber: 2  TL Phase 0 _ GGrrGGrr(41.0 s) _ next phase at 41.0s
# ExampleListener called at time 3.0 ms.
#  #EB approaching TL : 0  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# None
#
# _______________(step 3): Delta = 1.0 s  _  # MinExpectedNumber: 54  TL Phase 0 _ GGrrGGrr(41.0 s) _ next phase at 41.0s
# ExampleListener called at time 4.0 ms.
#  #EB approaching TL : 0  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# None
#
# _______________(step 4): Delta = 1.0 s  _  # MinExpectedNumber: 54  TL Phase 0 _ GGrrGGrr(41.0 s) _ next phase at 41.0s
# ExampleListener called at time 5.0 ms.
#  #EB approaching TL : 0  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'WestBound_0': {64: 3.1388614661991596, 122: 0.0}}
#
# _______________(step 5): Delta = 1.0 s  _  # MinExpectedNumber: 54  TL Phase 0 _ GGrrGGrr(41.0 s) _ next phase at 41.0s
# ExampleListener called at time 6.0 ms.
#  #EB approaching TL : 0  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'WestBound_0': {64: 3.624913378525525, 122: 0.0}}
#
# _______________(step 6): Delta = 1.0 s  _  # MinExpectedNumber: 54  TL Phase 0 _ GGrrGGrr(41.0 s) _ next phase at 41.0s
# ExampleListener called at time 7.0 ms.
#  #EB approaching TL : 0  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'WestBound_0': {64: 4.356133222393691, 122: 0.0}}
#
# _______________(step 7): Delta = 1.0 s  _  # MinExpectedNumber: 54  TL Phase 0 _ GGrrGGrr(41.0 s) _ next phase at 41.0s
# ExampleListener called at time 8.0 ms.
#  #EB approaching TL : 1  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_2': {64: 2.4134719179011888, 122: 0.0}, 'NorthBound_3': {64: 1.9153085446916522, 122: 0.0}, 'WestBound_0': {64: 4.852115104347466, 122: 0.0}}
#
# _______________(step 8): Delta = 1.0 s  _  # MinExpectedNumber: 54  TL Phase 0 _ GGrrGGrr(41.0 s) _ next phase at 41.0s
# ExampleListener called at time 9.0 ms.
#  #EB approaching TL : 1  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_2': {64: 3.026651603076608, 122: 0.0}, 'NorthBound_3': {64: 2.4658449539914726, 122: 0.0}, 'WestBound_0': {64: 5.544208902679382, 122: 0.0}}
#
# _______________(step 9): Delta = 1.0 s  _  # MinExpectedNumber: 54  TL Phase 0 _ GGrrGGrr(41.0 s) _ next phase at 41.0s
# ExampleListener called at time 10.0 ms.
#  #EB approaching TL : 1  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_2': {64: 3.595647951494904, 122: 0.0}, 'NorthBound_3': {64: 3.1139536388218403, 122: 0.0}, 'WestBound_0': {64: 6.224740898702292, 122: 0.0}, 'WestBound_1': {64: 2.452180655525613, 122: 0.0}}

# %%
junc_id = traci.junction.getIDList()

# %%
sumoBinary
# Out:
# '/usr/local/opt/sumo/share/sumo/bin/sumo-gui'

# %%
# !ps ax | grep sumo-gui
# Out:
# 65892   ??  S      0:00.95 /usr/local/opt/sumo/share/sumo/bin/sumo-gui -c data/road.sumocfg --tripinfo-output tripinfo.xml --remote-port 50452
# 66137 s006  Ss+    0:00.02 /bin/sh -c ps ax | grep sumo-gui
# 66139 s006  S+     0:00.01 grep sumo-gui

# %%
class Env_TLC:
    """
    Class for Traffic Light Control Environment which is used for retrieving State,
    changing the traffic phases or duration via TRACI API

    """

    def __init__(self, programID, tlsID):
        self.ID = tlsID
        self.programID = programID
        self.lanes = traci.trafficlight.getControlledLanes(self.ID)
        self.links = traci.trafficlight.getControlledLinks(lgt_1)
        self.RYG_definition = traci.trafficlight.getCompleteRedYellowGreenDefinition(lgt_1)
        self.last_state = {}
        
        self.IBlaneList = [self.links[i][0][0]for i in range(len(self.links))]
        self.OBlaneList = [self.links[i][0][1]for i in range(len(self.links))]
        self.linkList = [self.links[i][0][2]for i in range(len(self.links))]
    
    def getStateArray(state):
        return np.row_stack([np.array(each) for each in tl0.last_state.values()])

    def updateLastState(self, ):

        self.last_state['IBOccupancy'] = [traci.lane.getLastStepOccupancy(
            laneID) for laneID in self.IBlaneList]
        self.last_state['IBVolume'] = [traci.lane.getLastStepVehicleNumber(
            laneID) for laneID in self.IBlaneList]
        self.last_state['IBMeanSpeed'] = [traci.lane.getLastStepMeanSpeed(
            laneID) for laneID in self.IBlaneList]
        self.last_state['IBQueuSize'] = [traci.lane.getLastStepHaltingNumber(
            laneID) for laneID in self.IBlaneList]
        self.last_state['IBWaitingTime'] = [traci.lane.getWaitingTime(
            laneID) for laneID in self.IBlaneList]

        self.last_state['OBOccupancy'] = [traci.lane.getLastStepOccupancy(
            laneID) for laneID in self.OBlaneList]
        self.last_state['OBVolume'] = [traci.lane.getLastStepVehicleNumber(
            laneID) for laneID in self.OBlaneList]
        self.last_state['OBMeanSpeed'] = [traci.lane.getLastStepMeanSpeed(
            laneID) for laneID in self.IBlaneList]
        self.last_state['OBQueuSize'] = [traci.lane.getLastStepHaltingNumber(
            laneID) for laneID in self.OBlaneList]
        self.last_state['OBWaitingTime'] = [traci.lane.getWaitingTime(
            laneID) for laneID in self.OBlaneList]

# %%
tfcLgts =traci.trafficlight.getIDList()
lgt_1 = tfcLgts[0]
light1_Logic = traci.trafficlight.getCompleteRedYellowGreenDefinition(lgt_1)[0]

# %%
tl0 = Env_TLC(programID=light1_Logic.programID, tlsID=lgt_1)

# %%
tl0.updateLastState()
state = tl0.getStateArray()

# %%
tl0.last_state.keys()

# %%
light1_Logic

# %%
tl0.links[0][0]

# %%
from traci import trafficlight as TL
from traci import lane as Ln
from traci import simulation as Sim

# %%
TL.getNextSwitch(lgt_1)

# %%
TL.setParameter(lgt_1, param='programID', value='testSetParam')

# %%
TL.getProgram('tl0')

# %%
Sim.saveState('test_save_state.xml')

# %%
TL.getPhase('tl0')

# %%
light1_Logic

# %%
light1_Logic.currentPhaseIndex

# %%
tc.CMD_GET_VEHICLE_VARIABLE

# %%
traci.junction.subscribeContext("tl0", tc.CMD_GET_VEHICLE_VARIABLE, 300, [tc.VAR_SPEED, tc.VAR_WAITING_TIME])

# %%
light1_Logic.phases[0]

# %%
light1_Logic = traci.trafficlight.getCompleteRedYellowGreenDefinition(lgt_1)[0]

# %%
light1_Logic

# %%
TL.setCompleteRedYellowGreenDefinition(lgt_1, light1_Logic)

# %%
phases = light1_Logic.getPhases()

# %%
phases

# %%
phases[(TL.getPhase(lgt_1) + 2) % 4].duration = 50

# %%
TL.setCompleteRedYellowGreenDefinition(lgt_1, light1_Logic)

# %%
TL.getCompleteRedYellowGreenDefinition(lgt_1)

# %%
current_duration = TL.getCompleteRedYellowGreenDefinition(lgt_1)[0].getPhases()[(TL.getPhase(lgt_1)) % 4].duration
next_duration = TL.getCompleteRedYellowGreenDefinition(lgt_1)[0].getPhases()[(TL.getPhase(lgt_1) + 2) % 4].duration
print(current_duration)
next_duration

# %%
TL.getNextSwitch(lgt_1)

# %%
traci.simulation.getTime()

# %%
TL.getPhase(lgt_1)

# %%
print(f'at time {traci.simulation.getTime()}     Phase before: {TL.getPhase(lgt_1)}')
traci.simulationStep()
print(f'at time {traci.simulation.getTime()}     Phase after: {TL.getPhase(lgt_1)}')

# %%
class testListen(traci.StepListener):
    def step(self, t=0):

        print(f'at time {traci.simulation.getTime()}      During:   {TL.getPhase(lgt_1)}')

        return True

test_listen = testListen()
traci.addStepListener(test_listen)

# %%
def Stop():
    try:
        traci.close(False)
    except Exception as e:
        pass
    return

# %%
def Restart():
    traci.start([sumoBinary, '-c', 'data/road.sumocfg', '--load-state', 'test_save_state.xml', '--output-prefix', 'TIME']) 
    return

# %%
run()
# Out:
# {'EastBound_122': {64: 3.02248143637724, 122: 0.0}, 'EastBound_125': {64: 14.348034219164408, 122: 0.0}, 'EastBound_126': {64: 9.826344391517344, 122: 0.0}, 'EastBound_127': {64: 6.897016803175211, 122: 0.0}, 'EastBound_135': {64: 2.428692129254341, 122: 0.0}, 'NorthBound_130': {64: 9.26513050077483, 122: 0.0}, 'SouthBound_120': {64: 15.524716057825342, 122: 0.0}, 'SouthBound_123': {64: 4.7567908845308, 122: 0.0}, 'SouthBound_128': {64: 10.732421405427162, 122: 0.0}, 'SouthBound_132': {64: 5.999725664593279, 122: 0.0}, 'SouthBound_133': {64: 1.86436680406332, 122: 0.0}, 'WestBound_117': {64: 3.504378092475236, 122: 0.0}, 'WestBound_124': {64: 16.619253268446776, 122: 0.0}, 'WestBound_129': {64: 9.603915431164204, 122: 0.0}, 'WestBound_131': {64: 5.907877949718385, 122: 0.0}, 'WestBound_134': {64: 3.09933735365209, 122: 0.0}}
#
# _______________(step 0): Delta = 1.0 s  _  # MinExpectedNumber: 50  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 502.0 ms.
# at time 502.0      During:   2
#  #EB approaching TL : 4  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 3.4827396390976735, 122: 0.0}, 'EastBound_125': {64: 14.844688456878073, 122: 0.0}, 'EastBound_126': {64: 10.621140624023978, 122: 0.0}, 'EastBound_127': {64: 7.610469422675669, 122: 0.0}, 'EastBound_135': {64: 3.1995372071862223, 122: 0.0}, 'NorthBound_130': {64: 9.757581286318601, 122: 0.0}, 'SouthBound_120': {64: 15.615501461840676, 122: 0.0}, 'SouthBound_123': {64: 0.5056985818021633, 122: 0.0}, 'SouthBound_128': {64: 11.15387249346823, 122: 0.0}, 'SouthBound_132': {64: 6.782643295824527, 122: 0.0}, 'SouthBound_133': {64: 2.450021403003484, 122: 0.0}, 'WestBound_117': {64: 4.0363713082857435, 122: 0.0}, 'WestBound_124': {64: 16.553738008327784, 122: 0.0}, 'WestBound_129': {64: 10.338754042331129, 122: 0.0}, 'WestBound_131': {64: 6.581874984502791, 122: 0.0}, 'WestBound_134': {64: 3.5181373243236242, 122: 0.0}}
#
# _______________(step 1): Delta = 1.0 s  _  # MinExpectedNumber: 50  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 503.0 ms.
# at time 503.0      During:   2
#  #EB approaching TL : 4  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 4.037862913219107, 122: 0.0}, 'EastBound_125': {64: 15.49585105301813, 122: 0.0}, 'EastBound_126': {64: 11.257997093535964, 122: 0.0}, 'EastBound_127': {64: 8.185929787624628, 122: 0.0}, 'EastBound_135': {64: 3.8388584561645986, 122: 0.0}, 'NorthBound_130': {64: 10.248371813446285, 122: 0.0}, 'SouthBound_123': {64: 0.16174019522546612, 122: 0.0}, 'SouthBound_128': {64: 11.945447573624557, 122: 0.0}, 'SouthBound_132': {64: 7.34389583878219, 122: 0.0}, 'SouthBound_133': {64: 2.9953645416535437, 122: 0.0}, 'WestBound_117': {64: 4.637464369647205, 122: 0.0}, 'WestBound_124': {64: 16.651687515974047, 122: 0.0}, 'WestBound_129': {64: 10.993838413711638, 122: 0.0}, 'WestBound_131': {64: 7.111544835567473, 122: 0.0}, 'WestBound_134': {64: 3.936905668491244, 122: 0.0}}
#
# _______________(step 2): Delta = 1.0 s  _  # MinExpectedNumber: 50  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 504.0 ms.
# at time 504.0      During:   2
#  #EB approaching TL : 4  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 4.813189409023, 122: 0.0}, 'EastBound_125': {64: 16.271498962864285, 122: 0.0}, 'EastBound_126': {64: 11.976976276934153, 122: 0.0}, 'EastBound_127': {64: 8.880158712062986, 122: 0.0}, 'EastBound_135': {64: 4.35632078833878, 122: 0.0}, 'NorthBound_130': {64: 10.801675514690581, 122: 0.0}, 'SouthBound_123': {64: 0.00999427258835666, 122: 1.0}, 'SouthBound_128': {64: 12.63925971202553, 122: 0.0}, 'SouthBound_132': {64: 7.748368455935269, 122: 0.0}, 'SouthBound_133': {64: 3.434175306558609, 122: 0.0}, 'WestBound_117': {64: 5.326496069598943, 122: 0.0}, 'WestBound_124': {64: 16.45753414610401, 122: 0.0}, 'WestBound_129': {64: 11.56956822341308, 122: 0.0}, 'WestBound_131': {64: 7.908343986980616, 122: 0.0}, 'WestBound_134': {64: 4.723284463213503, 122: 0.0}}
#
# _______________(step 3): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 505.0 ms.
# at time 505.0      During:   2
#  #EB approaching TL : 4  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 5.286196746772004, 122: 0.0}, 'EastBound_125': {64: 16.552579795829953, 122: 0.0}, 'EastBound_126': {64: 12.704859702568507, 122: 0.0}, 'EastBound_127': {64: 9.373870494309815, 122: 0.0}, 'EastBound_135': {64: 4.991714681778102, 122: 0.0}, 'NorthBound_130': {64: 11.344353243336085, 122: 0.0}, 'SouthBound_123': {64: 0.0048311040305655285, 122: 2.0}, 'SouthBound_128': {64: 13.317863957397647, 122: 0.0}, 'SouthBound_132': {64: 8.430946893617511, 122: 0.0}, 'SouthBound_133': {64: 3.858773109316826, 122: 0.0}, 'WestBound_117': {64: 5.783360234089196, 122: 0.0}, 'WestBound_124': {64: 16.512418681643904, 122: 0.0}, 'WestBound_129': {64: 12.102566942945124, 122: 0.0}, 'WestBound_131': {64: 8.497684402763841, 122: 0.0}, 'WestBound_134': {64: 5.358123831359415, 122: 0.0}}
#
# _______________(step 4): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 506.0 ms.
# at time 506.0      During:   2
#  #EB approaching TL : 5  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 5.946143845749868, 122: 0.0}, 'EastBound_125': {64: 16.53296568065882, 122: 0.0}, 'EastBound_126': {64: 13.366601988207556, 122: 0.0}, 'EastBound_127': {64: 9.966043364163491, 122: 0.0}, 'EastBound_135': {64: 5.433096907846629, 122: 0.0}, 'EastBound_137': {64: 2.5682438979856674, 122: 0.0}, 'NorthBound_130': {64: 11.822911798860883, 122: 0.0}, 'SouthBound_123': {64: 0.004086858798277006, 122: 3.0}, 'SouthBound_128': {64: 13.750898507516839, 122: 0.0}, 'SouthBound_132': {64: 9.082713405415417, 122: 0.0}, 'SouthBound_133': {64: 4.3728599882684644, 122: 0.0}, 'WestBound_117': {64: 6.315417974349112, 122: 0.0}, 'WestBound_124': {64: 16.522269868366422, 122: 0.0}, 'WestBound_129': {64: 12.630087372381242, 122: 0.0}, 'WestBound_131': {64: 9.051946815196423, 122: 0.0}, 'WestBound_134': {64: 5.776767113527028, 122: 0.0}}
#
# _______________(step 5): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 507.0 ms.
# at time 507.0      During:   2
#  #EB approaching TL : 5  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 6.562247589977306, 122: 0.0}, 'EastBound_125': {64: 16.40423090884462, 122: 0.0}, 'EastBound_126': {64: 13.870286627952018, 122: 0.0}, 'EastBound_127': {64: 10.3771714755334, 122: 0.0}, 'EastBound_135': {64: 5.845422156061976, 122: 0.0}, 'EastBound_137': {64: 3.1310546462424105, 122: 0.0}, 'NorthBound_130': {64: 12.492096706200396, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 4.0}, 'SouthBound_128': {64: 14.205852622259416, 122: 0.0}, 'SouthBound_132': {64: 9.845521651580931, 122: 0.0}, 'SouthBound_133': {64: 5.031326242070644, 122: 0.0}, 'SouthBound_136': {64: 1.5969592002046324, 122: 0.0}, 'WestBound_117': {64: 6.812646511383355, 122: 0.0}, 'WestBound_124': {64: 16.482277293205264, 122: 0.0}, 'WestBound_129': {64: 13.238680455368014, 122: 0.0}, 'WestBound_131': {64: 9.610897611454128, 122: 0.0}, 'WestBound_134': {64: 6.201500624326734, 122: 0.0}}
#
# _______________(step 6): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 508.0 ms.
# at time 508.0      During:   2
#  #EB approaching TL : 5  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 7.3132119179720405, 122: 0.0}, 'EastBound_125': {64: 16.658468133471906, 122: 0.0}, 'EastBound_126': {64: 14.48533018734307, 122: 0.0}, 'EastBound_127': {64: 10.909901176299904, 122: 0.0}, 'EastBound_135': {64: 6.300188997481017, 122: 0.0}, 'EastBound_137': {64: 3.6696633887477224, 122: 0.0}, 'NorthBound_130': {64: 12.937474711611873, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 5.0}, 'SouthBound_128': {64: 14.80303563531489, 122: 0.0}, 'SouthBound_132': {64: 10.297986309975387, 122: 0.0}, 'SouthBound_133': {64: 5.763325840234756, 122: 0.0}, 'SouthBound_136': {64: 2.267630300094656, 122: 0.0}, 'WestBound_117': {64: 7.411221977323294, 122: 0.0}, 'WestBound_124': {64: 16.33562017761171, 122: 0.0}, 'WestBound_129': {64: 13.709712451137605, 122: 0.0}, 'WestBound_131': {64: 10.340736222919077, 122: 0.0}, 'WestBound_134': {64: 6.835142495577899, 122: 0.0}}
#
# _______________(step 7): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 509.0 ms.
# at time 509.0      During:   2
#  #EB approaching TL : 4  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 8.052082990670426, 122: 0.0}, 'EastBound_125': {64: 16.27875203795731, 122: 0.0}, 'EastBound_126': {64: 15.118969262857, 122: 0.0}, 'EastBound_127': {64: 11.628872854541992, 122: 0.0}, 'EastBound_135': {64: 7.021473369840531, 122: 0.0}, 'EastBound_137': {64: 4.159851840138436, 122: 0.0}, 'NorthBound_130': {64: 13.357385317701853, 122: 0.0}, 'SouthBound_123': {64: 0.00015855276961332983, 122: 6.0}, 'SouthBound_128': {64: 15.412308865319947, 122: 0.0}, 'SouthBound_132': {64: 10.807668252103033, 122: 0.0}, 'SouthBound_133': {64: 6.171640410926192, 122: 0.0}, 'SouthBound_136': {64: 3.0483096328389863, 122: 0.0}, 'WestBound_117': {64: 7.88437796290964, 122: 0.0}, 'WestBound_124': {64: 16.540112291164697, 122: 0.0}, 'WestBound_129': {64: 14.200076382514093, 122: 0.0}, 'WestBound_131': {64: 11.09960321718827, 122: 0.0}, 'WestBound_134': {64: 7.459349443299439, 122: 0.0}}
#
# _______________(step 8): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 510.0 ms.
# at time 510.0      During:   2
#  #EB approaching TL : 4  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 8.497959078570679, 122: 0.0}, 'EastBound_125': {64: 16.51315873840824, 122: 0.0}, 'EastBound_126': {64: 15.574521360360096, 122: 0.0}, 'EastBound_127': {64: 12.10573768522591, 122: 0.0}, 'EastBound_135': {64: 7.513377539720384, 122: 0.0}, 'EastBound_137': {64: 4.800053872354329, 122: 0.0}, 'NorthBound_130': {64: 13.762455295119443, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 7.0}, 'SouthBound_128': {64: 16.057011797931054, 122: 0.0}, 'SouthBound_132': {64: 11.474028615560385, 122: 0.0}, 'SouthBound_133': {64: 6.713928207568823, 122: 0.0}, 'SouthBound_136': {64: 3.5332392005075732, 122: 0.0}, 'WestBound_117': {64: 8.65075520919636, 122: 0.0}, 'WestBound_124': {64: 16.490441710110755, 122: 0.0}, 'WestBound_129': {64: 14.955686915665868, 122: 0.0}, 'WestBound_131': {64: 11.725400265026838, 122: 0.0}, 'WestBound_134': {64: 7.906883626432833, 122: 0.0}}
#
# _______________(step 9): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 511.0 ms.
# at time 511.0      During:   2
#  #EB approaching TL : 4  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 9.034174923693612, 122: 0.0}, 'EastBound_125': {64: 16.360787666606843, 122: 0.0}, 'EastBound_126': {64: 16.352222253754743, 122: 0.0}, 'EastBound_127': {64: 12.868693778850144, 122: 0.0}, 'EastBound_135': {64: 8.128022450581192, 122: 0.0}, 'EastBound_137': {64: 5.597965779155493, 122: 0.0}, 'NorthBound_130': {64: 14.498966505471627, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 8.0}, 'SouthBound_128': {64: 16.507319789007315, 122: 0.0}, 'SouthBound_132': {64: 12.134203319810334, 122: 0.0}, 'SouthBound_133': {64: 7.170800830330698, 122: 0.0}, 'SouthBound_136': {64: 4.2500407907937685, 122: 0.0}, 'WestBound_117': {64: 9.43437585514039, 122: 0.0}, 'WestBound_124': {64: 16.644031265359374, 122: 0.0}, 'WestBound_129': {64: 15.644107106234882, 122: 0.0}, 'WestBound_131': {64: 12.507240313384683, 122: 0.0}, 'WestBound_134': {64: 8.568943785225716, 122: 0.0}}
#
# _______________(step 10): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 512.0 ms.
# at time 512.0      During:   2
#  #EB approaching TL : 4  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 9.566820386426375, 122: 0.0}, 'EastBound_125': {64: 14.759716701940885, 122: 0.0}, 'EastBound_126': {64: 16.593537711426617, 122: 0.0}, 'EastBound_127': {64: 13.404129741434014, 122: 0.0}, 'EastBound_135': {64: 8.751886967290192, 122: 0.0}, 'EastBound_137': {64: 6.187243501935154, 122: 0.0}, 'NorthBound_130': {64: 15.156921014748525, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 9.0}, 'SouthBound_128': {64: 16.985155350156138, 122: 0.0}, 'SouthBound_132': {64: 12.791078557726, 122: 0.0}, 'SouthBound_133': {64: 7.663248362205921, 122: 0.0}, 'SouthBound_136': {64: 5.026626404078028, 122: 0.0}, 'WestBound_117': {64: 10.000223030243072, 122: 0.0}, 'WestBound_124': {64: 16.612087057512255, 122: 0.0}, 'WestBound_129': {64: 16.150299511291088, 122: 0.0}, 'WestBound_131': {64: 13.071069906558844, 122: 0.0}, 'WestBound_134': {64: 9.356436750294385, 122: 0.0}}
#
# _______________(step 11): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 513.0 ms.
# at time 513.0      During:   2
#  #EB approaching TL : 4  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 10.261666826439875, 122: 0.0}, 'EastBound_125': {64: 15.214462279309771, 122: 0.0}, 'EastBound_126': {64: 16.542923593409363, 122: 0.0}, 'EastBound_127': {64: 13.502122492168763, 122: 0.0}, 'EastBound_135': {64: 9.273410650808364, 122: 0.0}, 'EastBound_137': {64: 6.665419002529234, 122: 0.0}, 'NorthBound_130': {64: 15.777822043932986, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 10.0}, 'SouthBound_128': {64: 16.018444448121798, 122: 0.0}, 'SouthBound_132': {64: 13.422593904938553, 122: 0.0}, 'SouthBound_133': {64: 8.077106531895694, 122: 0.0}, 'SouthBound_136': {64: 5.62726636918383, 122: 0.0}, 'WestBound_117': {64: 10.796780139766637, 122: 0.0}, 'WestBound_124': {64: 16.419310681782665, 122: 0.0}, 'WestBound_129': {64: 16.3036877014488, 122: 0.0}, 'WestBound_131': {64: 13.532638632785531, 122: 0.0}, 'WestBound_134': {64: 9.81611022437152, 122: 0.0}}
#
# _______________(step 12): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 514.0 ms.
# at time 514.0      During:   2
#  #EB approaching TL : 4  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 10.765990441387373, 122: 0.0}, 'EastBound_125': {64: 15.741641606916927, 122: 0.0}, 'EastBound_126': {64: 16.585500268898905, 122: 0.0}, 'EastBound_127': {64: 13.6888751605644, 122: 0.0}, 'EastBound_135': {64: 9.978732209838928, 122: 0.0}, 'EastBound_137': {64: 7.114200582448393, 122: 0.0}, 'NorthBound_130': {64: 16.266029014717798, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 11.0}, 'SouthBound_128': {64: 11.744972908343792, 122: 0.0}, 'SouthBound_132': {64: 14.119491684436804, 122: 0.0}, 'SouthBound_133': {64: 8.861331530939786, 122: 0.0}, 'SouthBound_136': {64: 6.232079429255149, 122: 0.0}, 'WestBound_117': {64: 11.30134517513216, 122: 0.0}, 'WestBound_124': {64: 16.386328563354912, 122: 0.0}, 'WestBound_129': {64: 16.58217620112002, 122: 0.0}, 'WestBound_131': {64: 14.14180465601385, 122: 0.0}, 'WestBound_134': {64: 10.403078428657471, 122: 0.0}}
#
# _______________(step 13): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 515.0 ms.
# at time 515.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 11.28367735315286, 122: 0.0}, 'EastBound_125': {64: 16.50893267138421, 122: 0.0}, 'EastBound_126': {64: 16.510954362228514, 122: 0.0}, 'EastBound_127': {64: 13.420275997568586, 122: 0.0}, 'EastBound_135': {64: 10.38633694285527, 122: 0.0}, 'EastBound_137': {64: 7.590434251911938, 122: 0.0}, 'NorthBound_130': {64: 16.726319861691458, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 12.0}, 'SouthBound_128': {64: 7.6886984906491245, 122: 0.0}, 'SouthBound_132': {64: 14.640543471183635, 122: 0.0}, 'SouthBound_133': {64: 9.656463972758502, 122: 0.0}, 'SouthBound_136': {64: 6.963959263433984, 122: 0.0}, 'WestBound_117': {64: 12.066395150497561, 122: 0.0}, 'WestBound_124': {64: 16.41306705109775, 122: 0.0}, 'WestBound_129': {64: 16.403147097006443, 122: 0.0}, 'WestBound_131': {64: 14.617658448405567, 122: 0.0}, 'WestBound_134': {64: 10.813050510549663, 122: 0.0}}
#
# _______________(step 14): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 516.0 ms.
# at time 516.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 11.759206801095834, 122: 0.0}, 'EastBound_125': {64: 16.519162633530797, 122: 0.0}, 'EastBound_126': {64: 16.439820495322348, 122: 0.0}, 'EastBound_127': {64: 13.649367536802508, 122: 0.0}, 'EastBound_135': {64: 10.812217136565597, 122: 0.0}, 'EastBound_137': {64: 8.09788553342223, 122: 0.0}, 'NorthBound_130': {64: 13.316056211356997, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 13.0}, 'SouthBound_128': {64: 3.1886984906491245, 122: 0.0}, 'SouthBound_132': {64: 15.39331913301722, 122: 0.0}, 'SouthBound_133': {64: 10.33955600494519, 122: 0.0}, 'SouthBound_136': {64: 7.427048916352263, 122: 0.0}, 'SouthBound_138': {64: 1.7904864841140806, 122: 0.0}, 'WestBound_117': {64: 12.671731193363673, 122: 0.0}, 'WestBound_124': {64: 16.488714220169932, 122: 0.0}, 'WestBound_129': {64: 16.44236656062305, 122: 0.0}, 'WestBound_131': {64: 15.383838636428122, 122: 0.0}, 'WestBound_134': {64: 11.514119969589382, 122: 0.0}}
#
# _______________(step 15): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 517.0 ms.
# at time 517.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 12.332872337849668, 122: 0.0}, 'EastBound_125': {64: 16.29315105041489, 122: 0.0}, 'EastBound_126': {64: 16.338620217684657, 122: 0.0}, 'EastBound_127': {64: 13.493637486559072, 122: 0.0}, 'EastBound_135': {64: 11.30232148068026, 122: 0.0}, 'EastBound_137': {64: 8.711315719317644, 122: 0.0}, 'NorthBound_130': {64: 9.025092249645217, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 14.0}, 'SouthBound_128': {64: 0.01364863233750168, 122: 1.0}, 'SouthBound_132': {64: 15.816470862964712, 122: 0.0}, 'SouthBound_133': {64: 10.956300182174893, 122: 0.0}, 'SouthBound_136': {64: 8.074757045396886, 122: 0.0}, 'SouthBound_138': {64: 2.563113893009722, 122: 0.0}, 'WestBound_117': {64: 13.079228424839682, 122: 0.0}, 'WestBound_124': {64: 16.567996250819416, 122: 0.0}, 'WestBound_129': {64: 16.5454788662307, 122: 0.0}, 'WestBound_131': {64: 16.02319941520691, 122: 0.0}, 'WestBound_134': {64: 11.92361249178809, 122: 0.0}}
#
# _______________(step 16): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 518.0 ms.
# at time 518.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 12.913335993608317, 122: 0.0}, 'EastBound_125': {64: 16.598208022657783, 122: 0.0}, 'EastBound_126': {64: 16.389245007820428, 122: 0.0}, 'EastBound_127': {64: 13.490853610460379, 122: 0.0}, 'EastBound_135': {64: 11.981465129740538, 122: 0.0}, 'EastBound_137': {64: 9.14592093359679, 122: 0.0}, 'NorthBound_130': {64: 4.668976800192432, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 15.0}, 'SouthBound_128': {64: 0.004893333079038029, 122: 2.0}, 'SouthBound_132': {64: 15.692856262384526, 122: 0.0}, 'SouthBound_133': {64: 11.679693761840465, 122: 0.0}, 'SouthBound_136': {64: 8.691336660349094, 122: 0.0}, 'SouthBound_138': {64: 3.3094742993824187, 122: 0.0}, 'WestBound_117': {64: 13.493220994528391, 122: 0.0}, 'WestBound_124': {64: 16.531287747230383, 122: 0.0}, 'WestBound_129': {64: 16.314184150639925, 122: 0.0}, 'WestBound_131': {64: 16.3692321966216, 122: 0.0}, 'WestBound_134': {64: 12.655215174799533, 122: 0.0}}
#
# _______________(step 17): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 519.0 ms.
# at time 519.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 13.517401867547862, 122: 0.0}, 'EastBound_125': {64: 16.63426248615608, 122: 0.0}, 'EastBound_126': {64: 16.463340395670386, 122: 0.0}, 'EastBound_127': {64: 13.309410431806661, 122: 0.0}, 'EastBound_135': {64: 12.549186755251142, 122: 0.0}, 'EastBound_137': {64: 9.654807377140969, 122: 0.0}, 'NorthBound_130': {64: 0.7584104176166752, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 16.0}, 'SouthBound_128': {64: 0.0026192403540921897, 122: 3.0}, 'SouthBound_132': {64: 15.765877356140486, 122: 0.0}, 'SouthBound_133': {64: 12.113886743318293, 122: 0.0}, 'SouthBound_136': {64: 9.413530132436478, 122: 0.0}, 'SouthBound_138': {64: 4.10237022060901, 122: 0.0}, 'WestBound_117': {64: 14.223845792468646, 122: 0.0}, 'WestBound_124': {64: 16.323232522029432, 122: 0.0}, 'WestBound_129': {64: 16.48865203641355, 122: 0.0}, 'WestBound_131': {64: 16.608018860574813, 122: 0.0}, 'WestBound_134': {64: 13.332163118200125, 122: 0.0}}
#
# _______________(step 18): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 520.0 ms.
# at time 520.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 13.935775649083638, 122: 0.0}, 'EastBound_125': {64: 16.566778184268625, 122: 0.0}, 'EastBound_126': {64: 16.646242705434563, 122: 0.0}, 'EastBound_127': {64: 13.620863228955038, 122: 0.0}, 'EastBound_135': {64: 13.254110580310229, 122: 0.0}, 'EastBound_137': {64: 10.182984716352076, 122: 0.0}, 'NorthBound_130': {64: 0.03211611143464461, 122: 1.0}, 'SouthBound_123': {64: 0.0, 122: 17.0}, 'SouthBound_128': {64: 0.0005254644702030703, 122: 4.0}, 'SouthBound_132': {64: 15.748516858655124, 122: 0.0}, 'SouthBound_133': {64: 12.842440101969991, 122: 0.0}, 'SouthBound_136': {64: 10.171378777438129, 122: 0.0}, 'SouthBound_138': {64: 4.810508688353003, 122: 0.0}, 'WestBound_117': {64: 14.981165326945494, 122: 0.0}, 'WestBound_129': {64: 16.306088781617582, 122: 0.0}, 'WestBound_131': {64: 16.446853584032507, 122: 0.0}, 'WestBound_134': {64: 13.839015200083825, 122: 0.0}}
#
# _______________(step 19): Delta = 1.0 s  _  # MinExpectedNumber: 49  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 521.0 ms.
# at time 521.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 14.544291857166076, 122: 0.0}, 'EastBound_125': {64: 16.62155305331573, 122: 0.0}, 'EastBound_126': {64: 16.312787178605795, 122: 0.0}, 'EastBound_127': {64: 13.468550543778308, 122: 0.0}, 'EastBound_135': {64: 13.765985459927474, 122: 0.0}, 'EastBound_137': {64: 10.661959685012699, 122: 0.0}, 'NorthBound_130': {64: 0.015502391185906149, 122: 2.0}, 'SouthBound_123': {64: 0.0, 122: 18.0}, 'SouthBound_128': {64: 0.00034056899321027013, 122: 5.0}, 'SouthBound_132': {64: 11.464712227142515, 122: 0.0}, 'SouthBound_133': {64: 13.325484466645872, 122: 0.0}, 'SouthBound_136': {64: 10.671348587126758, 122: 0.0}, 'SouthBound_138': {64: 5.5426819115877155, 122: 0.0}, 'WestBound_117': {64: 15.775269806571316, 122: 0.0}, 'WestBound_129': {64: 16.662597290407867, 122: 0.0}, 'WestBound_131': {64: 16.595173609890047, 122: 0.0}, 'WestBound_134': {64: 14.46527452124444, 122: 0.0}}
#
# _______________(step 20): Delta = 1.0 s  _  # MinExpectedNumber: 48  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 522.0 ms.
# at time 522.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 15.217812780665096, 122: 0.0}, 'EastBound_125': {64: 16.291226135268808, 122: 0.0}, 'EastBound_126': {64: 16.655790143627677, 122: 0.0}, 'EastBound_127': {64: 13.42126452756367, 122: 0.0}, 'EastBound_135': {64: 14.445712758880115, 122: 0.0}, 'EastBound_137': {64: 11.37634257907048, 122: 0.0}, 'NorthBound_130': {64: 0.0025792584787824925, 122: 3.0}, 'SouthBound_123': {64: 0.0, 122: 19.0}, 'SouthBound_128': {64: 0.00011183557877989939, 122: 6.0}, 'SouthBound_132': {64: 6.991894741316429, 122: 0.0}, 'SouthBound_133': {64: 13.766023406945175, 122: 0.0}, 'SouthBound_136': {64: 11.295690189657089, 122: 0.0}, 'SouthBound_138': {64: 5.993751961551607, 122: 0.0}, 'WestBound_117': {64: 16.41144319130109, 122: 0.0}, 'WestBound_129': {64: 16.437623283620926, 122: 0.0}, 'WestBound_131': {64: 16.396159733720125, 122: 0.0}, 'WestBound_134': {64: 15.018446651475255, 122: 0.0}}
#
# _______________(step 21): Delta = 1.0 s  _  # MinExpectedNumber: 48  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 523.0 ms.
# at time 523.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 15.840427234491196, 122: 0.0}, 'EastBound_125': {64: 16.41406555173919, 122: 0.0}, 'EastBound_126': {64: 16.44428461974487, 122: 0.0}, 'EastBound_127': {64: 13.667702785704948, 122: 0.0}, 'EastBound_135': {64: 14.915122863464065, 122: 0.0}, 'EastBound_137': {64: 12.031842053867878, 122: 0.0}, 'EastBound_139': {64: 2.6629927523434165, 122: 0.0}, 'NorthBound_130': {64: 0.0005006213533741472, 122: 4.0}, 'SouthBound_123': {64: 0.0, 122: 20.0}, 'SouthBound_128': {64: 0.0, 122: 7.0}, 'SouthBound_132': {64: 2.5123844106282482, 122: 0.0}, 'SouthBound_133': {64: 14.385402608010924, 122: 0.0}, 'SouthBound_136': {64: 11.798449307848987, 122: 0.0}, 'SouthBound_138': {64: 6.43424010630697, 122: 0.0}, 'WestBound_117': {64: 16.342213679831477, 122: 0.0}, 'WestBound_129': {64: 16.27827113259584, 122: 0.0}, 'WestBound_131': {64: 16.34420186456293, 122: 0.0}, 'WestBound_134': {64: 15.669823137858634, 122: 0.0}}
#
# _______________(step 22): Delta = 1.0 s  _  # MinExpectedNumber: 48  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 524.0 ms.
# at time 524.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 16.53027002867484, 122: 0.0}, 'EastBound_125': {64: 16.58399382464588, 122: 0.0}, 'EastBound_126': {64: 16.61619500245899, 122: 0.0}, 'EastBound_127': {64: 13.466040859755793, 122: 0.0}, 'EastBound_135': {64: 15.519805772416301, 122: 0.0}, 'EastBound_137': {64: 12.445721646212045, 122: 0.0}, 'EastBound_139': {64: 3.1776222452521328, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 5.0}, 'SouthBound_123': {64: 0.0, 122: 21.0}, 'SouthBound_128': {64: 0.0, 122: 8.0}, 'SouthBound_132': {64: 0.07067676964606277, 122: 1.0}, 'SouthBound_133': {64: 15.097292750142522, 122: 0.0}, 'SouthBound_136': {64: 12.371566902735559, 122: 0.0}, 'SouthBound_138': {64: 6.8659432996064425, 122: 0.0}, 'WestBound_117': {64: 16.64222694680095, 122: 0.0}, 'WestBound_129': {64: 16.55112821634859, 122: 0.0}, 'WestBound_131': {64: 16.27478637572378, 122: 0.0}, 'WestBound_134': {64: 16.200577220042916, 122: 0.0}}
#
# _______________(step 23): Delta = 1.0 s  _  # MinExpectedNumber: 48  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 525.0 ms.
# at time 525.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 16.28891410155222, 122: 0.0}, 'EastBound_125': {64: 16.40648224407807, 122: 0.0}, 'EastBound_126': {64: 16.315332251116637, 122: 0.0}, 'EastBound_127': {64: 13.43677193346686, 122: 0.0}, 'EastBound_135': {64: 16.26099875178189, 122: 0.0}, 'EastBound_137': {64: 13.157094941381368, 122: 0.0}, 'EastBound_139': {64: 3.77862771069631, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 6.0}, 'SouthBound_123': {64: 0.0, 122: 22.0}, 'SouthBound_128': {64: 0.0, 122: 9.0}, 'SouthBound_132': {64: 0.01628644466273099, 122: 2.0}, 'SouthBound_133': {64: 15.607503317110249, 122: 0.0}, 'SouthBound_136': {64: 12.917299794574557, 122: 0.0}, 'SouthBound_138': {64: 7.442623344622552, 122: 0.0}, 'WestBound_117': {64: 16.61870643252507, 122: 0.0}, 'WestBound_129': {64: 16.378561126142742, 122: 0.0}, 'WestBound_131': {64: 16.55223533248529, 122: 0.0}, 'WestBound_134': {64: 16.5848679045029, 122: 0.0}}
#
# _______________(step 24): Delta = 1.0 s  _  # MinExpectedNumber: 48  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 526.0 ms.
# at time 526.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 16.644784996919334, 122: 0.0}, 'EastBound_125': {64: 16.54208543531597, 122: 0.0}, 'EastBound_126': {64: 16.581675613559785, 122: 0.0}, 'EastBound_127': {64: 13.510348540090689, 122: 0.0}, 'EastBound_135': {64: 16.66635361172259, 122: 0.0}, 'EastBound_137': {64: 13.899247051496063, 122: 0.0}, 'EastBound_139': {64: 4.343595902901143, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 7.0}, 'SouthBound_123': {64: 0.0, 122: 23.0}, 'SouthBound_128': {64: 0.0, 122: 10.0}, 'SouthBound_132': {64: 0.0014039140100084219, 122: 3.0}, 'SouthBound_133': {64: 16.276709215063608, 122: 0.0}, 'SouthBound_136': {64: 13.617464043648273, 122: 0.0}, 'SouthBound_138': {64: 7.9634688340127475, 122: 0.0}, 'WestBound_117': {64: 16.366697729453445, 122: 0.0}, 'WestBound_129': {64: 16.455768402554096, 122: 0.0}, 'WestBound_131': {64: 16.477882712036372, 122: 0.0}, 'WestBound_134': {64: 16.405270582232625, 122: 0.0}}
#
# _______________(step 25): Delta = 1.0 s  _  # MinExpectedNumber: 48  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 527.0 ms.
# at time 527.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 16.493620970454067, 122: 0.0}, 'EastBound_125': {64: 16.4776453384012, 122: 0.0}, 'EastBound_126': {64: 16.669343782942743, 122: 0.0}, 'EastBound_127': {64: 13.54961212511427, 122: 0.0}, 'EastBound_135': {64: 16.596733089890332, 122: 0.0}, 'EastBound_137': {64: 14.495196824800228, 122: 0.0}, 'EastBound_139': {64: 5.02981921210885, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 8.0}, 'SouthBound_123': {64: 0.0, 122: 24.0}, 'SouthBound_128': {64: 0.0, 122: 11.0}, 'SouthBound_132': {64: 0.0, 122: 4.0}, 'SouthBound_133': {64: 16.180218392581413, 122: 0.0}, 'SouthBound_136': {64: 14.358505571523041, 122: 0.0}, 'SouthBound_138': {64: 8.629160736873747, 122: 0.0}, 'WestBound_117': {64: 16.385972761251033, 122: 0.0}, 'WestBound_129': {64: 16.496995811983943, 122: 0.0}, 'WestBound_131': {64: 16.3357433972694, 122: 0.0}, 'WestBound_134': {64: 16.352336450647563, 122: 0.0}}
#
# _______________(step 26): Delta = 1.0 s  _  # MinExpectedNumber: 48  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 528.0 ms.
# at time 528.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_122': {64: 16.50112606247887, 122: 0.0}, 'EastBound_126': {64: 16.349896486364308, 122: 0.0}, 'EastBound_127': {64: 13.416727025539346, 122: 0.0}, 'EastBound_135': {64: 16.442192521952094, 122: 0.0}, 'EastBound_137': {64: 15.22230654377491, 122: 0.0}, 'EastBound_139': {64: 5.540695753227919, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 9.0}, 'SouthBound_123': {64: 0.0, 122: 25.0}, 'SouthBound_128': {64: 0.0, 122: 12.0}, 'SouthBound_132': {64: 0.0, 122: 5.0}, 'SouthBound_133': {64: 11.779236572889655, 122: 0.0}, 'SouthBound_136': {64: 15.089093243499578, 122: 0.0}, 'SouthBound_138': {64: 9.192106517218054, 122: 0.0}, 'WestBound_129': {64: 16.646028531976047, 122: 0.0}, 'WestBound_131': {64: 16.366742505021396, 122: 0.0}, 'WestBound_134': {64: 16.5772186104022, 122: 0.0}}
#
# _______________(step 27): Delta = 1.0 s  _  # MinExpectedNumber: 47  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 529.0 ms.
# at time 529.0      During:   2
#  #EB approaching TL : 2  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_126': {64: 16.273183797467503, 122: 0.0}, 'EastBound_127': {64: 13.676133458048769, 122: 0.0}, 'EastBound_135': {64: 16.423965469915423, 122: 0.0}, 'EastBound_137': {64: 15.991501965187497, 122: 0.0}, 'EastBound_139': {64: 6.264673222415149, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 10.0}, 'NorthBound_141': {64: 2.0581364557147026, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 26.0}, 'SouthBound_128': {64: 0.0, 122: 13.0}, 'SouthBound_132': {64: 0.0, 122: 6.0}, 'SouthBound_133': {64: 7.279236572889655, 122: 0.0}, 'SouthBound_136': {64: 15.513344683294477, 122: 0.0}, 'SouthBound_138': {64: 9.828005886357278, 122: 0.0}, 'SouthBound_140': {64: 1.502515544742346, 122: 0.0}, 'WestBound_129': {64: 16.658416529074312, 122: 0.0}, 'WestBound_131': {64: 16.516811131481084, 122: 0.0}, 'WestBound_134': {64: 16.468767421673984, 122: 0.0}}
#
# _______________(step 28): Delta = 1.0 s  _  # MinExpectedNumber: 45  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 530.0 ms.
# at time 530.0      During:   2
#  #EB approaching TL : 2  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_126': {64: 16.434785433188082, 122: 0.0}, 'EastBound_127': {64: 13.599382119265117, 122: 0.0}, 'EastBound_135': {64: 16.582689357809723, 122: 0.0}, 'EastBound_137': {64: 16.49775216493756, 122: 0.0}, 'EastBound_139': {64: 6.788625140395014, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 11.0}, 'NorthBound_141': {64: 2.5486376013606784, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 27.0}, 'SouthBound_128': {64: 0.0, 122: 14.0}, 'SouthBound_132': {64: 0.0, 122: 7.0}, 'SouthBound_133': {64: 7.679734545761764, 122: 0.0}, 'SouthBound_136': {64: 16.24387297349173, 122: 0.0}, 'SouthBound_138': {64: 10.496412289235742, 122: 0.0}, 'SouthBound_140': {64: 2.082921549677849, 122: 0.0}, 'WestBound_129': {64: 16.54495591333136, 122: 0.0}, 'WestBound_131': {64: 16.32123189520091, 122: 0.0}, 'WestBound_134': {64: 16.32060885967687, 122: 0.0}}
#
# _______________(step 29): Delta = 1.0 s  _  # MinExpectedNumber: 45  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 531.0 ms.
# at time 531.0      During:   2
#  #EB approaching TL : 2  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_126': {64: 16.632454795837404, 122: 0.0}, 'EastBound_127': {64: 13.411584614787914, 122: 0.0}, 'EastBound_135': {64: 16.357225786875937, 122: 0.0}, 'EastBound_137': {64: 16.46914344130084, 122: 0.0}, 'EastBound_139': {64: 7.562104776594786, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 12.0}, 'NorthBound_141': {64: 3.1098624830134214, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 28.0}, 'SouthBound_128': {64: 0.0, 122: 15.0}, 'SouthBound_132': {64: 0.0, 122: 8.0}, 'SouthBound_133': {64: 4.91145184172704, 122: 0.0}, 'SouthBound_136': {64: 16.966057224647436, 122: 0.0}, 'SouthBound_138': {64: 11.294964316114786, 122: 0.0}, 'SouthBound_140': {64: 2.741093537677079, 122: 0.0}, 'WestBound_129': {64: 16.28816895902157, 122: 0.0}, 'WestBound_131': {64: 16.322128166798503, 122: 0.0}, 'WestBound_134': {64: 16.395913213565947, 122: 0.0}}
#
# _______________(step 30): Delta = 1.0 s  _  # MinExpectedNumber: 45  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 532.0 ms.
# at time 532.0      During:   2
#  #EB approaching TL : 2  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_126': {64: 16.561409817337992, 122: 0.0}, 'EastBound_127': {64: 13.44385529385201, 122: 0.0}, 'EastBound_135': {64: 16.50976022684947, 122: 0.0}, 'EastBound_137': {64: 16.571115513034165, 122: 0.0}, 'EastBound_139': {64: 8.12898941328749, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 13.0}, 'NorthBound_141': {64: 3.711246965453029, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 29.0}, 'SouthBound_128': {64: 0.0, 122: 16.0}, 'SouthBound_132': {64: 0.0, 122: 9.0}, 'SouthBound_133': {64: 0.41145184172703964, 122: 0.0}, 'SouthBound_136': {64: 15.68626503476369, 122: 0.0}, 'SouthBound_138': {64: 11.775049597211186, 122: 0.0}, 'SouthBound_140': {64: 3.443123471643775, 122: 0.0}, 'WestBound_129': {64: 16.497553925197572, 122: 0.0}, 'WestBound_131': {64: 16.552221490330997, 122: 0.0}, 'WestBound_134': {64: 16.285158410929146, 122: 0.0}}
#
# _______________(step 31): Delta = 1.0 s  _  # MinExpectedNumber: 45  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 533.0 ms.
# at time 533.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_126': {64: 16.290886256732048, 122: 0.0}, 'EastBound_127': {64: 13.320616589405306, 122: 0.0}, 'EastBound_135': {64: 16.535339552331717, 122: 0.0}, 'EastBound_137': {64: 16.63258619343862, 122: 0.0}, 'EastBound_139': {64: 8.67946981396526, 122: 0.0}, 'EastBound_142': {64: 2.6304138532839714, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 14.0}, 'NorthBound_141': {64: 4.186049425508828, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 30.0}, 'SouthBound_128': {64: 0.0, 122: 17.0}, 'SouthBound_132': {64: 0.0, 122: 10.0}, 'SouthBound_133': {64: 0.1453960398265465, 122: 0.0}, 'SouthBound_136': {64: 11.384144270117007, 122: 0.0}, 'SouthBound_138': {64: 12.313923951610928, 122: 0.0}, 'SouthBound_140': {64: 4.023098452854901, 122: 0.0}, 'WestBound_129': {64: 16.4615785683319, 122: 0.0}, 'WestBound_131': {64: 16.552390950527045, 122: 0.0}, 'WestBound_134': {64: 16.396901654154064, 122: 0.0}}
#
# _______________(step 32): Delta = 1.0 s  _  # MinExpectedNumber: 45  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 534.0 ms.
# at time 534.0      During:   2
#  #EB approaching TL : 2  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_127': {64: 13.584819708683261, 122: 0.0}, 'EastBound_135': {64: 16.470920735206455, 122: 0.0}, 'EastBound_137': {64: 16.561109457891437, 122: 0.0}, 'EastBound_139': {64: 9.152480645570904, 122: 0.0}, 'EastBound_142': {64: 3.3675424139946695, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 15.0}, 'NorthBound_141': {64: 4.882785282842816, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 31.0}, 'SouthBound_128': {64: 0.0, 122: 18.0}, 'SouthBound_132': {64: 0.0, 122: 11.0}, 'SouthBound_133': {64: 0.02765229815132065, 122: 1.0}, 'SouthBound_136': {64: 7.097052695159408, 122: 0.0}, 'SouthBound_138': {64: 13.08736658925191, 122: 0.0}, 'SouthBound_140': {64: 4.782286755554377, 122: 0.0}, 'WestBound_129': {64: 16.460018432121725, 122: 0.0}, 'WestBound_131': {64: 16.290559576526285, 122: 0.0}, 'WestBound_134': {64: 16.345033983681354, 122: 0.0}}
#
# _______________(step 33): Delta = 1.0 s  _  # MinExpectedNumber: 45  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 535.0 ms.
# at time 535.0      During:   2
#  #EB approaching TL : 2  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_127': {64: 13.359063066088327, 122: 0.0}, 'EastBound_135': {64: 16.478935110364112, 122: 0.0}, 'EastBound_137': {64: 16.471096986979248, 122: 0.0}, 'EastBound_139': {64: 9.863931069988759, 122: 0.0}, 'EastBound_142': {64: 3.873728531040251, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 16.0}, 'NorthBound_141': {64: 5.569492720346899, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 32.0}, 'SouthBound_128': {64: 0.0, 122: 19.0}, 'SouthBound_132': {64: 0.0, 122: 12.0}, 'SouthBound_133': {64: 0.01086809332444855, 122: 2.0}, 'SouthBound_136': {64: 2.597052695159408, 122: 0.0}, 'SouthBound_138': {64: 13.506630443688488, 122: 0.0}, 'SouthBound_140': {64: 5.360983792506158, 122: 0.0}, 'SouthBound_144': {64: 1.93010693192482, 122: 0.0}, 'WestBound_129': {64: 16.52510079963133, 122: 0.0}, 'WestBound_131': {64: 16.531532747652385, 122: 0.0}, 'WestBound_134': {64: 16.45667832519859, 122: 0.0}}
#
# _______________(step 34): Delta = 1.0 s  _  # MinExpectedNumber: 44  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 536.0 ms.
# at time 536.0      During:   2
#  #EB approaching TL : 2  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_127': {64: 13.63277229798279, 122: 0.0}, 'EastBound_135': {64: 16.394111918825658, 122: 0.0}, 'EastBound_137': {64: 16.467468760050835, 122: 0.0}, 'EastBound_139': {64: 10.468887164257469, 122: 0.0}, 'EastBound_142': {64: 4.342055157385767, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 17.0}, 'NorthBound_141': {64: 6.221721802465619, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 33.0}, 'SouthBound_128': {64: 0.0, 122: 20.0}, 'SouthBound_132': {64: 0.0, 122: 13.0}, 'SouthBound_133': {64: 0.0031555051077334067, 122: 3.0}, 'SouthBound_136': {64: 0.051281821896616904, 122: 1.0}, 'SouthBound_138': {64: 14.26524331392721, 122: 0.0}, 'SouthBound_140': {64: 5.877096544206141, 122: 0.0}, 'SouthBound_144': {64: 2.4559939336031675, 122: 0.0}, 'WestBound_131': {64: 16.530947766993197, 122: 0.0}, 'WestBound_134': {64: 16.612689622193578, 122: 0.0}}
#
# _______________(step 35): Delta = 1.0 s  _  # MinExpectedNumber: 43  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 536.0s
# ExampleListener called at time 537.0 ms.
# at time 537.0      During:   3
#  #EB approaching TL : 2  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_127': {64: 13.386479652219185, 122: 0.0}, 'EastBound_135': {64: 16.445138919148597, 122: 0.0}, 'EastBound_137': {64: 16.283235096633437, 122: 0.0}, 'EastBound_139': {64: 11.23310797289014, 122: 0.0}, 'EastBound_142': {64: 4.998128332570196, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 18.0}, 'NorthBound_141': {64: 6.734633902925999, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 34.0}, 'SouthBound_128': {64: 0.0, 122: 21.0}, 'SouthBound_132': {64: 0.0, 122: 14.0}, 'SouthBound_133': {64: 0.0, 122: 4.0}, 'SouthBound_136': {64: 0.0012400934729456274, 122: 2.0}, 'SouthBound_138': {64: 14.998628160916276, 122: 0.0}, 'SouthBound_140': {64: 6.344518412090837, 122: 0.0}, 'SouthBound_144': {64: 3.1350818805396554, 122: 0.0}, 'WestBound_131': {64: 16.649597739037127, 122: 0.0}, 'WestBound_134': {64: 16.536254920698703, 122: 0.0}}
#
# _______________(step 36): Delta = 1.0 s  _  # MinExpectedNumber: 43  TL Phase 3 _ rryyrryy(4.0 s) _ next phase at 540.0s
# ExampleListener called at time 538.0 ms.
# at time 538.0      During:   3
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_127': {64: 13.615223491296836, 122: 0.0}, 'EastBound_135': {64: 16.53347937239334, 122: 0.0}, 'EastBound_137': {64: 16.340825272053483, 122: 0.0}, 'EastBound_139': {64: 11.744469539728017, 122: 0.0}, 'EastBound_142': {64: 5.480139267537743, 122: 0.0}, 'EastBound_143': {64: 2.410377724468708, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 19.0}, 'NorthBound_141': {64: 7.143846411071719, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 35.0}, 'SouthBound_128': {64: 0.0, 122: 22.0}, 'SouthBound_132': {64: 0.0, 122: 15.0}, 'SouthBound_133': {64: 0.0, 122: 5.0}, 'SouthBound_136': {64: 0.00015339574958724903, 122: 3.0}, 'SouthBound_138': {64: 15.624118002131588, 122: 0.0}, 'SouthBound_140': {64: 7.012923726532607, 122: 0.0}, 'SouthBound_144': {64: 3.583957703411579, 122: 0.0}, 'WestBound_131': {64: 16.310215205401185, 122: 0.0}, 'WestBound_134': {64: 16.44323271520436, 122: 0.0}}
#
# _______________(step 37): Delta = 1.0 s  _  # MinExpectedNumber: 43  TL Phase 3 _ rryyrryy(4.0 s) _ next phase at 540.0s
# ExampleListener called at time 539.0 ms.
# at time 539.0      During:   3
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_127': {64: 13.321212288190344, 122: 0.0}, 'EastBound_135': {64: 16.628353549335152, 122: 0.0}, 'EastBound_137': {64: 16.622768936287613, 122: 0.0}, 'EastBound_139': {64: 12.412313544098291, 122: 0.0}, 'EastBound_142': {64: 5.930421278532595, 122: 0.0}, 'EastBound_143': {64: 2.933484002016485, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 20.0}, 'NorthBound_141': {64: 7.547444071434439, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 36.0}, 'SouthBound_128': {64: 0.0, 122: 23.0}, 'SouthBound_132': {64: 0.0, 122: 16.0}, 'SouthBound_133': {64: 0.0, 122: 6.0}, 'SouthBound_136': {64: 0.0, 122: 4.0}, 'SouthBound_138': {64: 16.10766221163795, 122: 0.0}, 'SouthBound_140': {64: 7.514103065431117, 122: 0.0}, 'SouthBound_144': {64: 4.044139777030796, 122: 0.0}, 'WestBound_131': {64: 16.593711092025043, 122: 0.0}, 'WestBound_134': {64: 16.535152457077057, 122: 0.0}}
#
# _______________(step 38): Delta = 1.0 s  _  # MinExpectedNumber: 43  TL Phase 3 _ rryyrryy(4.0 s) _ next phase at 540.0s
# ExampleListener called at time 540.0 ms.
# at time 540.0      During:   3
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_127': {64: 13.464380687393913, 122: 0.0}, 'EastBound_135': {64: 16.506385423410684, 122: 0.0}, 'EastBound_137': {64: 16.647689304668457, 122: 0.0}, 'EastBound_139': {64: 12.8587976760231, 122: 0.0}, 'EastBound_142': {64: 6.613225079700351, 122: 0.0}, 'EastBound_143': {64: 3.526678946521134, 122: 0.0}, 'NorthBound_130': {64: 0.0, 122: 21.0}, 'NorthBound_141': {64: 7.969503018911929, 122: 0.0}, 'SouthBound_123': {64: 0.0, 122: 37.0}, 'SouthBound_128': {64: 0.0, 122: 24.0}, 'SouthBound_132': {64: 0.0, 122: 17.0}, 'SouthBound_133': {64: 0.00011364269860372604, 122: 7.0}, 'SouthBound_136': {64: 0.0, 122: 5.0}, 'SouthBound_138': {64: 16.603064835481575, 122: 0.0}, 'SouthBound_140': {64: 8.262506883591413, 122: 0.0}, 'SouthBound_144': {64: 4.611709196120501, 122: 0.0}, 'WestBound_131': {64: 16.355013150423765, 122: 0.0}, 'WestBound_134': {64: 16.365252685341986, 122: 0.0}}
#
# _______________(step 39): Delta = 1.0 s  _  # MinExpectedNumber: 43  TL Phase 3 _ rryyrryy(4.0 s) _ next phase at 540.0s
# ExampleListener called at time 541.0 ms.
# at time 541.0      During:   0
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_127': {64: 13.31752001653678, 122: 0.0}, 'EastBound_135': {64: 16.63952001824975, 122: 0.0}, 'EastBound_137': {64: 16.52964458351955, 122: 0.0}, 'EastBound_139': {64: 13.656391328666365, 122: 0.0}, 'EastBound_142': {64: 7.255468499101698, 122: 0.0}, 'EastBound_143': {64: 4.270593014638871, 122: 0.0}, 'NorthBound_130': {64: 0.788965198583901, 122: 0.0}, 'NorthBound_141': {64: 8.738647477049383, 122: 0.0}, 'SouthBound_123': {64: 0.7682386630214751, 122: 0.0}, 'SouthBound_128': {64: 0.7896690236404539, 122: 0.0}, 'SouthBound_132': {64: 0.0, 122: 18.0}, 'SouthBound_133': {64: 0.0, 122: 8.0}, 'SouthBound_136': {64: 0.0, 122: 6.0}, 'SouthBound_138': {64: 12.71997782223284, 122: 0.0}, 'SouthBound_140': {64: 8.978059453796597, 122: 0.0}, 'SouthBound_144': {64: 5.303951416164637, 122: 0.0}, 'SouthBound_145': {64: 1.7752261705696584, 122: 0.0}, 'WestBound_134': {64: 16.371356170047076, 122: 0.0}}
#
# _______________(step 40): Delta = 1.0 s  _  # MinExpectedNumber: 43  TL Phase 0 _ GGrrGGrr(50.0 s) _ next phase at 590.0s
# ExampleListener called at time 542.0 ms.
# at time 542.0      During:   0
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_127': {64: 13.518663232878515, 122: 0.0}, 'EastBound_135': {64: 16.593327089380473, 122: 0.0}, 'EastBound_137': {64: 16.655617375466974, 122: 0.0}, 'EastBound_139': {64: 14.233844485227024, 122: 0.0}, 'EastBound_142': {64: 8.006123642250895, 122: 0.0}, 'EastBound_143': {64: 5.064211519435048, 122: 0.0}, 'NorthBound_130': {64: 1.5859020023606718, 122: 0.0}, 'NorthBound_141': {64: 9.40822926051915, 122: 0.0}, 'SouthBound_123': {64: 1.2122212279587985, 122: 0.0}, 'SouthBound_128': {64: 1.353951469156891, 122: 0.0}, 'SouthBound_132': {64: 0.7492307837903305, 122: 0.0}, 'SouthBound_133': {64: 0.5838542763245759, 122: 0.0}, 'SouthBound_136': {64: 0.0, 122: 7.0}, 'SouthBound_138': {64: 8.27465019792676, 122: 0.0}, 'SouthBound_140': {64: 9.534042680449787, 122: 0.0}, 'SouthBound_144': {64: 5.715144769940525, 122: 0.0}, 'SouthBound_145': {64: 2.188771834224463, 122: 0.0}, 'WestBound_134': {64: 16.530495749767873, 122: 0.0}}
#
# ...
# ExampleListener called at time 989.0 ms.
# at time 989.0      During:   1
#  #EB approaching TL : 8  _  # vehicles waiting: 5EB ttl waiting time: 159.0
# {'EastBound_256': {64: 0.0, 122: 49.0}, 'EastBound_257': {64: 0.0, 122: 44.0}, 'EastBound_261': {64: 0.0, 122: 29.0}, 'EastBound_263': {64: 0.0, 122: 20.0}, 'EastBound_264': {64: 0.0, 122: 17.0}, 'EastBound_269': {64: 16.337015319038183, 122: 0.0}, 'EastBound_273': {64: 7.849081594031303, 122: 0.0}, 'EastBound_275': {64: 3.6874318408779803, 122: 0.0}, 'NorthBound_271': {64: 13.770278954412792, 122: 0.0}, 'SouthBound_266': {64: 16.025750047973933, 122: 0.0}, 'SouthBound_274': {64: 6.9348596139810965, 122: 0.0}, 'WestBound_260': {64: 0.0, 122: 28.0}, 'WestBound_265': {64: 0.0, 122: 15.0}, 'WestBound_267': {64: 0.0, 122: 5.0}, 'WestBound_268': {64: 6.0985535977439485, 122: 0.0}, 'WestBound_270': {64: 12.748211192432798, 122: 0.0}, 'WestBound_272': {64: 10.204743283881562, 122: 0.0}}
#
# _______________(step 488): Delta = 1.0 s  _  # MinExpectedNumber: 27  TL Phase 1 _ yyrryyrr(4.0 s) _ next phase at 990.0s
# ExampleListener called at time 990.0 ms.
# at time 990.0      During:   1
#  #EB approaching TL : 8  _  # vehicles waiting: 5EB ttl waiting time: 164.0
# {'EastBound_256': {64: 0.0, 122: 50.0}, 'EastBound_257': {64: 0.0, 122: 45.0}, 'EastBound_261': {64: 0.0, 122: 30.0}, 'EastBound_263': {64: 0.0, 122: 21.0}, 'EastBound_264': {64: 0.0, 122: 18.0}, 'EastBound_269': {64: 14.542707098697663, 122: 0.0}, 'EastBound_273': {64: 8.646955550275742, 122: 0.0}, 'EastBound_275': {64: 4.09638149002567, 122: 0.0}, 'NorthBound_271': {64: 14.33493730893097, 122: 0.0}, 'SouthBound_266': {64: 15.981642481851967, 122: 0.0}, 'SouthBound_274': {64: 7.440848440118132, 122: 0.0}, 'WestBound_260': {64: 0.0, 122: 29.0}, 'WestBound_265': {64: 0.0, 122: 16.0}, 'WestBound_267': {64: 0.00010004347389011209, 122: 6.0}, 'WestBound_268': {64: 2.213371820579538, 122: 0.0}, 'WestBound_270': {64: 13.469052482768902, 122: 0.0}, 'WestBound_272': {64: 10.699860641254801, 122: 0.0}}
#
# _______________(step 489): Delta = 1.0 s  _  # MinExpectedNumber: 27  TL Phase 1 _ yyrryyrr(4.0 s) _ next phase at 990.0s
# ExampleListener called at time 991.0 ms.
# at time 991.0      During:   2
#  #EB approaching TL : 8  _  # vehicles waiting: 3EB ttl waiting time: 72.0
# {'EastBound_256': {64: 0.7934253091923893, 122: 0.0}, 'EastBound_257': {64: 0.7673588811419905, 122: 0.0}, 'EastBound_261': {64: 0.0, 122: 31.0}, 'EastBound_263': {64: 0.0, 122: 22.0}, 'EastBound_264': {64: 0.0, 122: 19.0}, 'EastBound_269': {64: 10.487471084936251, 122: 0.0}, 'EastBound_273': {64: 9.062062384746968, 122: 0.0}, 'EastBound_275': {64: 4.775871581118555, 122: 0.0}, 'NorthBound_271': {64: 14.280399267950273, 122: 0.0}, 'SouthBound_266': {64: 16.320117532629165, 122: 0.0}, 'SouthBound_274': {64: 7.86080285599455, 122: 0.0}, 'WestBound_260': {64: 0.622134926263243, 122: 0.0}, 'WestBound_265': {64: 0.7002353045158088, 122: 0.0}, 'WestBound_267': {64: 0.0, 122: 7.0}, 'WestBound_268': {64: 0.10499487914010319, 122: 0.0}, 'WestBound_270': {64: 13.97201849464328, 122: 0.0}, 'WestBound_272': {64: 11.128122468559761, 122: 0.0}}
#
# _______________(step 490): Delta = 1.0 s  _  # MinExpectedNumber: 27  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 1031.0s
# ExampleListener called at time 992.0 ms.
# at time 992.0      During:   2
#  #EB approaching TL : 6  _  # vehicles waiting: 1EB ttl waiting time: 20.0
# {'EastBound_256': {64: 1.3014021468348802, 122: 0.0}, 'EastBound_257': {64: 1.1937753045931458, 122: 0.0}, 'EastBound_261': {64: 0.6841687386363287, 122: 0.0}, 'EastBound_263': {64: 0.6598651730577109, 122: 0.0}, 'EastBound_264': {64: 0.0, 122: 20.0}, 'EastBound_269': {64: 5.987471084936251, 122: 0.0}, 'EastBound_273': {64: 9.841185675375163, 122: 0.0}, 'EastBound_275': {64: 5.3889674168080095, 122: 0.0}, 'NorthBound_271': {64: 14.408125016109265, 122: 0.0}, 'SouthBound_266': {64: 16.13395802861044, 122: 0.0}, 'SouthBound_274': {64: 8.555883390456437, 122: 0.0}, 'SouthBound_277': {64: 1.8970806031487883, 122: 0.0}, 'WestBound_260': {64: 1.3533652066253126, 122: 0.0}, 'WestBound_265': {64: 1.2734709106385709, 122: 0.0}, 'WestBound_267': {64: 0.36629965654058877, 122: 0.0}, 'WestBound_268': {64: 0.5201588317296888, 122: 0.0}, 'WestBound_270': {64: 14.480636961106221, 122: 0.0}, 'WestBound_272': {64: 11.851396044983288, 122: 0.0}}
#
# _______________(step 491): Delta = 1.0 s  _  # MinExpectedNumber: 27  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 1031.0s
# ExampleListener called at time 993.0 ms.
# at time 993.0      During:   2
#  #EB approaching TL : 6  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_256': {64: 1.8861822068691256, 122: 0.0}, 'EastBound_257': {64: 1.7372495915740729, 122: 0.0}, 'EastBound_261': {64: 1.0514731065980065, 122: 0.0}, 'EastBound_263': {64: 0.9605804429395554, 122: 0.0}, 'EastBound_264': {64: 0.35462911257342095, 122: 0.0}, 'EastBound_269': {64: 6.783587766985138, 122: 0.0}, 'EastBound_273': {64: 10.540349351055921, 122: 0.0}, 'EastBound_275': {64: 6.149244766496122, 122: 0.0}, 'NorthBound_271': {64: 14.227202214782304, 122: 0.0}, 'SouthBound_274': {64: 8.98247112315148, 122: 0.0}, 'SouthBound_277': {64: 2.6450739135034382, 122: 0.0}, 'WestBound_260': {64: 2.1327661707065997, 122: 0.0}, 'WestBound_265': {64: 1.9005960080772641, 122: 0.0}, 'WestBound_267': {64: 0.9176333779883248, 122: 0.0}, 'WestBound_268': {64: 1.0376222633301702, 122: 0.0}, 'WestBound_270': {64: 15.16371496031062, 122: 0.0}, 'WestBound_272': {64: 12.290485021645894, 122: 0.0}, 'WestBound_276': {64: 2.401120260823518, 122: 0.0}}
#
# _______________(step 492): Delta = 1.0 s  _  # MinExpectedNumber: 27  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 1031.0s
# ExampleListener called at time 994.0 ms.
# at time 994.0      During:   2
#  #EB approaching TL : 6  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_256': {64: 2.442129191290588, 122: 0.0}, 'EastBound_257': {64: 2.177311696577817, 122: 0.0}, 'EastBound_261': {64: 1.5456322797252704, 122: 0.0}, 'EastBound_263': {64: 1.652257167548543, 122: 0.0}, 'EastBound_264': {64: 1.1119290936534165, 122: 0.0}, 'EastBound_269': {64: 3.7690658509233788, 122: 0.0}, 'EastBound_273': {64: 10.966980757750573, 122: 0.0}, 'EastBound_275': {64: 6.763682448770851, 122: 0.0}, 'NorthBound_271': {64: 14.081529437207795, 122: 0.0}, 'SouthBound_274': {64: 9.472097142692656, 122: 0.0}, 'SouthBound_277': {64: 3.151915450301021, 122: 0.0}, 'WestBound_260': {64: 2.7150109415873884, 122: 0.0}, 'WestBound_265': {64: 2.4578465279191737, 122: 0.0}, 'WestBound_267': {64: 1.6346080633294446, 122: 0.0}, 'WestBound_268': {64: 1.47536972458581, 122: 0.0}, 'WestBound_270': {64: 15.664235496521007, 122: 0.0}, 'WestBound_272': {64: 12.732063295307329, 122: 0.0}, 'WestBound_276': {64: 3.0596203218214213, 122: 0.0}}
#
# _______________(step 493): Delta = 1.0 s  _  # MinExpectedNumber: 26  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 1031.0s
# ExampleListener called at time 995.0 ms.
# at time 995.0      During:   2
#  #EB approaching TL : 7  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_256': {64: 3.054599850438536, 122: 0.0}, 'EastBound_257': {64: 2.7708718814887106, 122: 0.0}, 'EastBound_261': {64: 2.0871485948241224, 122: 0.0}, 'EastBound_263': {64: 2.2624109724542554, 122: 0.0}, 'EastBound_264': {64: 1.5959385691378536, 122: 0.0}, 'EastBound_269': {64: 1.5341252802877412, 122: 0.0}, 'EastBound_273': {64: 11.68331515444443, 122: 0.0}, 'EastBound_275': {64: 7.392540349625051, 122: 0.0}, 'EastBound_279': {64: 2.147475872281939, 122: 0.0}, 'NorthBound_271': {64: 14.073724207298078, 122: 0.0}, 'SouthBound_274': {64: 10.055478269420565, 122: 0.0}, 'SouthBound_277': {64: 3.6594530330039556, 122: 0.0}, 'WestBound_260': {64: 3.3262160972692074, 122: 0.0}, 'WestBound_265': {64: 3.2030125636607414, 122: 0.0}, 'WestBound_267': {64: 2.222332913842486, 122: 0.0}, 'WestBound_268': {64: 2.1010658678143708, 122: 0.0}, 'WestBound_270': {64: 15.985697938109166, 122: 0.0}, 'WestBound_272': {64: 13.158485648768714, 122: 0.0}, 'WestBound_276': {64: 3.840092030353844, 122: 0.0}}
#
# _______________(step 494): Delta = 1.0 s  _  # MinExpectedNumber: 26  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 1031.0s
# ExampleListener called at time 996.0 ms.
# at time 996.0      During:   2
#  #EB approaching TL : 7  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_256': {64: 3.79842441873625, 122: 0.0}, 'EastBound_257': {64: 3.2260197523981335, 122: 0.0}, 'EastBound_261': {64: 2.5873071944950987, 122: 0.0}, 'EastBound_263': {64: 2.845348986611372, 122: 0.0}, 'EastBound_264': {64: 1.9526830215616875, 122: 0.0}, 'EastBound_269': {64: 2.15250128442484, 122: 0.0}, 'EastBound_273': {64: 12.193494118843232, 122: 0.0}, 'EastBound_275': {64: 7.894095624331386, 122: 0.0}, 'EastBound_279': {64: 2.6581952182576063, 122: 0.0}, 'NorthBound_271': {64: 14.27400129578746, 122: 0.0}, 'SouthBound_274': {64: 10.655938866548242, 122: 0.0}, 'SouthBound_277': {64: 4.094634774699807, 122: 0.0}, 'WestBound_260': {64: 3.7715863762423396, 122: 0.0}, 'WestBound_265': {64: 3.846192518435419, 122: 0.0}, 'WestBound_267': {64: 2.823259960715161, 122: 0.0}, 'WestBound_268': {64: 2.721456498979726, 122: 0.0}, 'WestBound_270': {64: 15.795665856430656, 122: 0.0}, 'WestBound_272': {64: 13.836596664122066, 122: 0.0}, 'WestBound_276': {64: 4.369555535539985, 122: 0.0}}
#
# _______________(step 495): Delta = 1.0 s  _  # MinExpectedNumber: 26  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 1031.0s
# ExampleListener called at time 997.0 ms.
# at time 997.0      During:   2
#  #EB approaching TL : 5  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_256': {64: 4.279585199337453, 122: 0.0}, 'EastBound_257': {64: 3.887900390382857, 122: 0.0}, 'EastBound_261': {64: 3.1674999342909924, 122: 0.0}, 'EastBound_263': {64: 3.1952405455504267, 122: 0.0}, 'EastBound_264': {64: 2.5893706191940957, 122: 0.0}, 'EastBound_269': {64: 2.6670110533020184, 122: 0.0}, 'EastBound_273': {64: 12.771862267423426, 122: 0.0}, 'EastBound_275': {64: 8.533483416959644, 122: 0.0}, 'EastBound_279': {64: 3.320900363847614, 122: 0.0}, 'NorthBound_271': {64: 14.256184346524245, 122: 0.0}, 'SouthBound_274': {64: 11.395899349730465, 122: 0.0}, 'SouthBound_277': {64: 4.798786469921469, 122: 0.0}, 'WestBound_260': {64: 4.280987139139325, 122: 0.0}, 'WestBound_265': {64: 4.536838971916587, 122: 0.0}, 'WestBound_267': {64: 3.5819992070500413, 122: 0.0}, 'WestBound_268': {64: 3.5046704061805687, 122: 0.0}, 'WestBound_270': {64: 15.793361612854875, 122: 0.0}, 'WestBound_272': {64: 14.280226601089112, 122: 0.0}, 'WestBound_276': {64: 5.05674857692793, 122: 0.0}}
#
# _______________(step 496): Delta = 1.0 s  _  # MinExpectedNumber: 26  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 1031.0s
# ExampleListener called at time 998.0 ms.
# at time 998.0      During:   2
#  #EB approaching TL : 5  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_256': {64: 5.015150146279485, 122: 0.0}, 'EastBound_257': {64: 4.310680134873838, 122: 0.0}, 'EastBound_261': {64: 3.9573497241972855, 122: 0.0}, 'EastBound_263': {64: 3.9327622138877123, 122: 0.0}, 'EastBound_264': {64: 3.0578977224095514, 122: 0.0}, 'EastBound_269': {64: 3.391011929885177, 122: 0.0}, 'EastBound_273': {64: 13.30501365140081, 122: 0.0}, 'EastBound_275': {64: 9.316536739561709, 122: 0.0}, 'EastBound_279': {64: 3.870023143198342, 122: 0.0}, 'NorthBound_271': {64: 11.52599017462957, 122: 0.0}, 'SouthBound_274': {64: 12.087061549816285, 122: 0.0}, 'SouthBound_277': {64: 5.496764778625219, 122: 0.0}, 'SouthBound_278': {64: 1.8361412205733365, 122: 0.0}, 'WestBound_260': {64: 4.969483682792633, 122: 0.0}, 'WestBound_265': {64: 5.1219566773623235, 122: 0.0}, 'WestBound_267': {64: 4.085986295476989, 122: 0.0}, 'WestBound_268': {64: 4.190594553622552, 122: 0.0}, 'WestBound_270': {64: 13.640268372554509, 122: 0.0}, 'WestBound_272': {64: 14.878115362941049, 122: 0.0}, 'WestBound_276': {64: 5.612700306251645, 122: 0.0}}
#
# _______________(step 497): Delta = 1.0 s  _  # MinExpectedNumber: 26  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 1031.0s
# ExampleListener called at time 999.0 ms.
# at time 999.0      During:   2
#  #EB approaching TL : 5  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_256': {64: 5.6146017417311676, 122: 0.0}, 'EastBound_257': {64: 4.900456807017327, 122: 0.0}, 'EastBound_261': {64: 4.368695066278326, 122: 0.0}, 'EastBound_263': {64: 4.174470079597996, 122: 0.0}, 'EastBound_264': {64: 3.616777976942693, 122: 0.0}, 'EastBound_269': {64: 4.087151050475119, 122: 0.0}, 'EastBound_273': {64: 13.906470809597527, 122: 0.0}, 'EastBound_275': {64: 9.792772773187611, 122: 0.0}, 'EastBound_279': {64: 4.577879052329809, 122: 0.0}, 'NorthBound_271': {64: 7.02599017462957, 122: 0.0}, 'SouthBound_274': {64: 12.56540630869568, 122: 0.0}, 'SouthBound_277': {64: 6.020935408305376, 122: 0.0}, 'SouthBound_278': {64: 2.479544816352428, 122: 0.0}, 'WestBound_260': {64: 5.492278262879699, 122: 0.0}, 'WestBound_265': {64: 5.731178273074329, 122: 0.0}, 'WestBound_267': {64: 4.779773898277864, 122: 0.0}, 'WestBound_268': {64: 4.962399398024329, 122: 0.0}, 'WestBound_270': {64: 10.424704385217606, 122: 0.0}, 'WestBound_272': {64: 15.505173992818914, 122: 0.0}, 'WestBound_276': {64: 6.202554677519947, 122: 0.0}}
#
# _______________(step 498): Delta = 1.0 s  _  # MinExpectedNumber: 26  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 1031.0s
# ExampleListener called at time 1000.0 ms.
# at time 1000.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_256': {64: 6.373639965988696, 122: 0.0}, 'EastBound_257': {64: 5.321920429542661, 122: 0.0}, 'EastBound_261': {64: 4.797770440546321, 122: 0.0}, 'EastBound_263': {64: 4.694109390770064, 122: 0.0}, 'EastBound_264': {64: 4.302241889727746, 122: 0.0}, 'EastBound_269': {64: 4.1343077342917, 122: 0.0}, 'EastBound_273': {64: 14.601890390925115, 122: 0.0}, 'EastBound_275': {64: 10.426396308559928, 122: 0.0}, 'EastBound_279': {64: 5.317503575328738, 122: 0.0}, 'NorthBound_271': {64: 2.5667444226451828, 122: 0.0}, 'SouthBound_274': {64: 13.055848021153368, 122: 0.0}, 'SouthBound_277': {64: 6.622547837067394, 122: 0.0}, 'SouthBound_278': {64: 2.9220435683615515, 122: 0.0}, 'WestBound_260': {64: 6.0789591213688245, 122: 0.0}, 'WestBound_265': {64: 6.219867169577628, 122: 0.0}, 'WestBound_267': {64: 5.288838454563603, 122: 0.0}, 'WestBound_268': {64: 5.50266949604372, 122: 0.0}, 'WestBound_270': {64: 8.392871822499513, 122: 0.0}, 'WestBound_272': {64: 16.131976714252257, 122: 0.0}, 'WestBound_276': {64: 6.722479567490518, 122: 0.0}}
#
# _______________(step 499): Delta = 1.0 s  _  # MinExpectedNumber: 26  TL Phase 2 _ rrGGrrGG(41.0 s) _ next phase at 1031.0s
# ExampleListener called at time 1001.0 ms.
# at time 1001.0      During:   2
#  #EB approaching TL : 3  _  # vehicles waiting: 0EB ttl waiting time: 0.0
# {'EastBound_256': {64: 6.993460737168789, 122: 0.0}, 'EastBound_257': {64: 5.826839557290078, 122: 0.0}, 'EastBound_261': {64: 5.565170266447114, 122: 0.0}, 'EastBound_263': {64: 5.349919062946902, 122: 0.0}, 'EastBound_264': {64: 4.846870579445247, 122: 0.0}, 'EastBound_269': {64: 4.833535076538999, 122: 0.0}, 'EastBound_273': {64: 15.255198121909059, 122: 0.0}, 'EastBound_275': {64: 10.884772331360733, 122: 0.0}, 'EastBound_279': {64: 5.891867437865585, 122: 0.0}, 'NorthBound_271': {64: 0.21371098029840152, 122: 0.0}, 'SouthBound_274': {64: 13.527822722122082, 122: 0.0}, 'SouthBound_277': {64: 7.3212108183652145, 122: 0.0}, 'SouthBound_278': {64: 3.36393274087459, 122: 0.0}, 'WestBound_260': {64: 6.813284810259937, 122: 0.0}, 'WestBound_265': {64: 6.806143799051642, 122: 0.0}, 'WestBound_267': {64: 6.0032493979152886, 122: 0.0}, 'WestBound_268': {64: 6.220919758315333, 122: 0.0}, 'WestBound_270': {64: 7.102828424579144, 122: 0.0}, 'WestBound_272': {64: 16.622393822185696, 122: 0.0}, 'WestBound_276': {64: 7.419405272044241, 122: 0.0}}

# %%
TL.getCompleteRedYellowGreenDefinition(lgt_1)[0].getPhases()[TL.getPhase(lgt_1)].duration
# Out:
# 41.0

# %%
TL.getPhaseDuration(lgt_1)
# Out:
# 41.0

# %%
light1_Logic.getPhases()[(TL.getPhase(lgt_1) + 2) % 4].duration
# Out:
# 50

# %%
laneareas = traci.lanearea.getIDList()

# %%
traci.constants.RESPONSE_SUBSCRIBE_LANEAREA_VARIABLE
# Out:
# 237

# %%
traci.lanearea.getContextSubscriptionResults(laneareas[0])

# %%
for i in range(50):
    value = traci.lanearea.getAllContextSubscriptionResults() 
    if len(value) is not 0  :  print(value)
    traci.simulation.step()
# Out:
# ExampleListener called at time 1002.0 ms.
# at time 1002.0      During:   2
# ExampleListener called at time 1003.0 ms.
# at time 1003.0      During:   2
# ExampleListener called at time 1004.0 ms.
# at time 1004.0      During:   2
# ExampleListener called at time 1005.0 ms.
# at time 1005.0      During:   2
# ExampleListener called at time 1006.0 ms.
# at time 1006.0      During:   2
# ExampleListener called at time 1007.0 ms.
# at time 1007.0      During:   2
# ExampleListener called at time 1008.0 ms.
# at time 1008.0      During:   2
# ExampleListener called at time 1009.0 ms.
# at time 1009.0      During:   2
# ExampleListener called at time 1010.0 ms.
# at time 1010.0      During:   2
# ExampleListener called at time 1011.0 ms.
# at time 1011.0      During:   2
# ExampleListener called at time 1012.0 ms.
# at time 1012.0      During:   2
# ExampleListener called at time 1013.0 ms.
# at time 1013.0      During:   2
# ExampleListener called at time 1014.0 ms.
# at time 1014.0      During:   2
# ExampleListener called at time 1015.0 ms.
# at time 1015.0      During:   2
# ExampleListener called at time 1016.0 ms.
# at time 1016.0      During:   2
# ExampleListener called at time 1017.0 ms.
# at time 1017.0      During:   2
# ExampleListener called at time 1018.0 ms.
# at time 1018.0      During:   2
# ExampleListener called at time 1019.0 ms.
# at time 1019.0      During:   2
# ExampleListener called at time 1020.0 ms.
# at time 1020.0      During:   2
# ExampleListener called at time 1021.0 ms.
# at time 1021.0      During:   2
# ExampleListener called at time 1022.0 ms.
# at time 1022.0      During:   2
# ExampleListener called at time 1023.0 ms.
# at time 1023.0      During:   2
# ExampleListener called at time 1024.0 ms.
# at time 1024.0      During:   2
# ExampleListener called at time 1025.0 ms.
# at time 1025.0      During:   2
# ExampleListener called at time 1026.0 ms.
# at time 1026.0      During:   2
# ExampleListener called at time 1027.0 ms.
# at time 1027.0      During:   2
# ExampleListener called at time 1028.0 ms.
# at time 1028.0      During:   2
# ExampleListener called at time 1029.0 ms.
# at time 1029.0      During:   2
# ExampleListener called at time 1030.0 ms.
# at time 1030.0      During:   2
# ExampleListener called at time 1031.0 ms.
# at time 1031.0      During:   2
# ExampleListener called at time 1032.0 ms.
# at time 1032.0      During:   3
# ExampleListener called at time 1033.0 ms.
# at time 1033.0      During:   3
# ExampleListener called at time 1034.0 ms.
# at time 1034.0      During:   3
# ExampleListener called at time 1035.0 ms.
# at time 1035.0      During:   3
# ExampleListener called at time 1036.0 ms.
# at time 1036.0      During:   0
# ExampleListener called at time 1037.0 ms.
# at time 1037.0      During:   0
# ExampleListener called at time 1038.0 ms.
# at time 1038.0      During:   0
# ExampleListener called at time 1039.0 ms.
# at time 1039.0      During:   0
# ExampleListener called at time 1040.0 ms.
# at time 1040.0      During:   0
# ExampleListener called at time 1041.0 ms.
# at time 1041.0      During:   0
# ExampleListener called at time 1042.0 ms.
# at time 1042.0      During:   0
# ExampleListener called at time 1043.0 ms.
# at time 1043.0      During:   0
# ExampleListener called at time 1044.0 ms.
# at time 1044.0      During:   0
# ExampleListener called at time 1045.0 ms.
# at time 1045.0      During:   0
# ExampleListener called at time 1046.0 ms.
# at time 1046.0      During:   0
# ExampleListener called at time 1047.0 ms.
# at time 1047.0      During:   0
# ExampleListener called at time 1048.0 ms.
# at time 1048.0      During:   0
# ExampleListener called at time 1049.0 ms.
# at time 1049.0      During:   0
# ExampleListener called at time 1050.0 ms.
# at time 1050.0      During:   0
# ExampleListener called at time 1051.0 ms.
# at time 1051.0      During:   0

# %%
StopnRestart()

# %%
import sumolib

# %%
output = sumolib.output.parse('data/e2output.xml', element_names=['interval'])

# %%
detector_output = []
for each in output:
    detector_output.append(each)

# %%
detector_output = [each for each in output]

# %%
detector_output[0].getAttributes()

# %%
from traci import lanearea as La

# %%
OBDetectors = La.getIDList()

# %%
Total_VehIds=[]
Current_VehIDs = []
for _ in range(800):
    for each in [list(La.getLastStepVehicleIDs(lane_area)) for lane_area in OBDetectors]:
        for ID in each:
            if ID not in Total_VehIds:
                Total_VehIds.append(ID)
    #LastStep_VehIDs = [list(La.getLastStepVehicleIDs(lane_area)) for lane_area in laneareas]
    traci.simulationStep()

# %%
Stop()
Restart()

# %%
len(TotalIds)

# %%
for each in [list(La.getLastStepVehicleIDs(lane_area)) for lane_area in OBDetectors]:
        for ID in each:
             Current_vehIDs.append(ID)

# %%
Current_vehIDs

# %%
def OB_nbr_VehLeft(seconds, OBDetectors):
    Starting_VehIDs = []
    Total_VehIDs = []
    Current_VehIDs = []
    
    # Query for Starting Vehicles in OBDetector Areas
    for each in [list(La.getLastStepVehicleIDs(lane_area)) for lane_area in OBDetectors]:
            for ID in each:
                 Starting_VehIDs.append(ID)
                    
    # Query for Total Vehicles in OBDetector Areas
    for _ in range(seconds):
        for each in [list(La.getLastStepVehicleIDs(lane_area)) for lane_area in OBDetectors]:
            for ID in each:
                if ID not in Total_VehIDs:
                    Total_VehIDs.append(ID)
        traci.simulationStep()
        
    # Query for remaining Vehicles in OBDetector Areas
    for each in [list(La.getLastStepVehicleIDs(lane_area)) for lane_area in OBDetectors]:
            for ID in each:
                 Current_vehIDs.append(ID)
    return len(Total_VehIDs) - len(Current_vehIDs) - len(Starting_VehIDs)

# %%
result = OB_nbr_VehLeft(60, OBDetectors= OBDetectors)

# %%
TL.getNextSwitch('tl0')

# %%
traci.simulation.getTime()

# %%
for _ in range(15): traci.simulationStep()

# %%
links = TL.getControlledLinks('tl0') 
IBlaneList = [links[i][0][0]for i in range(len(links))]

# %%
[Ln.getWaitingTime(lane) for lane in IBlaneList]

# %%
TL.getNextSwitch(lgt_1)

# %%
state_to_array(TL.getRedYellowGreenState(lgt_1))

# %%
from helper import state_to_array

# %%
laneareas

# %%
for each in laneareas: print(each)

# %%
type(laneareas)

# %%
a = np.random.random((10, 8))

# %%
b = np.random.random((24,8))
c = [0, 0, 0, 0, 0, 0, 0, 0]

# %%
a.shape
# Out:
# (10, 8)

# %%
b.shape
# Out:
# (24, 8)

# %%
c
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0]

# %%
np.row_stack((a, b, c))
# Out:
# array([[5.40608333e-01, 1.33322844e-01, 4.25301439e-01, 6.32043877e-01,
#         1.68328111e-01, 4.46178823e-01, 8.28744387e-01, 6.80077542e-02],
#        [6.14629061e-01, 6.07415179e-01, 8.02675079e-01, 1.54467476e-01,
#         3.85609940e-01, 3.21468195e-03, 5.69858920e-01, 7.19822679e-01],
#        [8.94131110e-02, 8.99352030e-01, 2.55428246e-01, 7.92502856e-01,
#         2.67668321e-01, 4.53778042e-01, 5.66488349e-01, 5.84213978e-01],
#        [3.87851569e-01, 8.05143551e-01, 9.56181722e-02, 9.26276946e-01,
#         2.60333346e-02, 8.39086331e-01, 9.69247872e-01, 1.83022568e-01],
#        [5.29808228e-01, 9.95667851e-01, 2.27801743e-01, 9.99501481e-01,
#         3.36593506e-01, 5.57150318e-01, 5.58733954e-01, 7.01784205e-01],
#        [9.95313825e-02, 4.75424242e-01, 2.33575022e-01, 4.38539576e-01,
#         5.21580025e-01, 7.01578199e-01, 2.45866271e-01, 8.78802364e-01],
#        [4.15627311e-02, 8.66703387e-01, 9.55184204e-01, 5.41995159e-01,
#         2.61963552e-01, 2.10623892e-01, 9.59619467e-01, 3.47466022e-03],
#        [7.49942379e-01, 8.62411732e-01, 6.95122916e-01, 7.96158451e-01,
#         8.29668541e-01, 1.64723484e-01, 8.99295816e-01, 6.48127679e-01],
#        [5.26118887e-01, 5.05721675e-01, 3.05735988e-01, 2.42151464e-01,
#         5.89068343e-01, 2.33024120e-01, 6.86886316e-01, 3.19432724e-01],
#        [8.18363183e-01, 5.26301845e-01, 9.66991668e-01, 4.60819874e-01,
#         8.64347135e-01, 5.86902765e-01, 5.90696705e-01, 6.17861932e-01],
#        [4.74884593e-01, 9.50594497e-02, 7.06581360e-01, 7.51681981e-01,
#         2.92612757e-01, 9.42351113e-01, 3.09015466e-01, 2.74302159e-01],
#        [1.10441176e-01, 1.44267903e-01, 8.55751868e-01, 1.79649250e-01,
#         1.90300188e-01, 1.52130196e-01, 6.23671543e-01, 1.10129541e-01],
#        [3.09415384e-01, 2.98437282e-01, 9.73701091e-01, 1.63542717e-01,
#         1.48551306e-01, 9.43775983e-01, 6.80211399e-01, 7.35356515e-01],
#        [2.40043259e-01, 9.87217320e-01, 5.43423269e-01, 5.51840057e-01,
#         1.45802755e-01, 2.95420290e-01, 8.09253763e-04, 4.27995260e-01],
#        [4.85024580e-02, 1.64365099e-01, 2.65313951e-02, 7.25787467e-01,
#         2.66948330e-01, 9.58436218e-01, 7.68813875e-01, 3.23028408e-01],
#        [3.56794138e-01, 4.62737065e-01, 3.25351180e-01, 8.01906650e-01,
#         6.62140341e-01, 9.99833038e-02, 3.60011416e-01, 8.47699808e-01],
#        [2.59417755e-01, 6.36415299e-01, 3.11930571e-01, 4.27963295e-01,
#         4.68271534e-01, 2.49537799e-02, 4.17052212e-01, 1.56027742e-01],
#        [1.31192823e-01, 4.68750510e-01, 5.53472098e-02, 7.87236884e-01,
#         1.79563982e-01, 3.78747333e-02, 9.57217634e-01, 1.49594630e-01],
#        [4.33711396e-02, 3.98257849e-01, 7.16620776e-01, 6.40789862e-01,
#         3.32301452e-01, 7.25587598e-01, 4.04684589e-01, 8.58104444e-01],
#        [1.74309387e-01, 6.54898740e-01, 5.79205764e-01, 6.29213165e-01,
#         9.77051513e-02, 4.90607661e-01, 8.23517660e-01, 4.87011893e-01],
#        [4.68106367e-01, 6.93152909e-01, 7.74156683e-01, 6.05338974e-01,
#         7.62248550e-01, 7.50563477e-02, 8.51194066e-01, 9.92244196e-01],
#        [4.56363235e-01, 6.76124767e-01, 3.09314375e-01, 2.37772985e-01,
#         4.59220796e-01, 3.76189720e-01, 9.17240452e-02, 6.49901564e-02],
#        [8.51619019e-01, 1.29467362e-01, 7.26696007e-01, 4.25135906e-01,
#         6.54002256e-01, 9.70384518e-01, 8.24763642e-01, 5.55198886e-01],
#        [9.22541674e-01, 9.56952613e-01, 1.56570132e-01, 4.78371082e-01,
#         8.24878616e-01, 6.56801893e-01, 1.59186425e-01, 7.96110547e-01],
#        [2.19987857e-01, 8.00530625e-01, 8.89139215e-01, 4.05905950e-01,
#         5.14080410e-01, 1.54498642e-01, 3.00862674e-01, 5.21587275e-01],
#        [5.59615092e-01, 9.32766007e-01, 8.49769632e-01, 9.86554248e-01,
#         6.82807143e-01, 9.23663744e-01, 7.46760295e-01, 9.62736395e-01],
#        [2.79169846e-01, 1.19904984e-01, 6.23725976e-01, 3.03492357e-01,
#         2.01603387e-01, 8.42347283e-01, 5.46743777e-02, 5.14499156e-01],
#        [9.53252350e-01, 7.83844547e-01, 1.38770459e-01, 4.21702957e-01,
#         2.47629806e-01, 1.59476106e-01, 3.14308733e-01, 4.70104110e-01],
#        [9.19493211e-01, 1.24982566e-01, 1.61563821e-01, 1.59839890e-03,
#         4.08182187e-01, 5.13918561e-01, 7.05808115e-02, 3.64704844e-02],
#        [2.88690521e-01, 9.58191006e-02, 2.36927951e-01, 5.37400065e-01,
#         4.38160131e-01, 6.33984472e-01, 7.19499370e-01, 1.57539418e-01],
#        [4.46603140e-01, 3.58976738e-01, 9.41303223e-01, 3.39372045e-01,
#         7.99679792e-01, 6.31569084e-01, 3.51732002e-01, 4.67847663e-01],
#        [2.79489455e-01, 4.53127429e-01, 4.70104200e-01, 7.61576008e-01,
#         4.64989922e-01, 9.41584532e-01, 8.56383305e-01, 9.72028785e-01],
#        [9.40324117e-01, 6.02602775e-01, 7.13222885e-01, 9.96646761e-02,
#         5.03406883e-01, 4.75741874e-01, 1.21271679e-01, 8.26854678e-01],
#        [2.65854002e-01, 2.75979815e-01, 6.25359668e-01, 8.89820655e-01,
#         4.83131930e-01, 3.01751923e-02, 5.96566607e-01, 5.94376753e-01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])
